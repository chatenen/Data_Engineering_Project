# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo
import json

# %%
client = pymongo.MongoClient('127.0.0.1', 27017) # Si utilisation en local
#client = pymongo.MongoClient('mongo') # Si utilisation d'une image Docker
database = client['exercices']
collection_ks = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                150000 non-null  int64
#  1   name              149998 non-null  object
#  2   category          150000 non-null  object
#  3   main_category     150000 non-null  object
#  4   currency          150000 non-null  object
#  5   deadline          150000 non-null  object
#  6   goal              150000 non-null  object
#  7   launched          150000 non-null  object
#  8   pledged           150000 non-null  object
#  9   state             150000 non-null  object
#  10  backers           150000 non-null  object
#  11  country           150000 non-null  object
#  12  usd pledged       148518 non-null  object
#  13  usd_pledged_real  150000 non-null  float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 16.0+ MB

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks = df_ks.rename(columns = {'usd pledged':'usd_pledged'})

# %%
lst_col_trait = ['goal', 'pledged', 'backers', 'usd_pledged']
col_name = 'name'

# %%
def traitement_table(df, lst_col_trait, name):
    for i in lst_col_trait:
        row_to_supp_goal = df[pd.to_numeric(df[i], errors ='coerce').isnull()].index
        df = df.drop(index = row_to_supp_goal)
        df[i] = df[i].astype(float)
    df[name] = df[name].astype('str')
    return df

# %%
df_ks = traitement_table(df_ks, lst_col_trait, col_name)

# %%
df_ks = df_ks.dropna()

# %%
df_ks.drop_duplicates(subset = 'name', keep = 'first', inplace=True)

# %%
df_ks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148015 entries, 0 to 149999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                148015 non-null  int64
#  1   name              148015 non-null  object
#  2   category          148015 non-null  object
#  3   main_category     148015 non-null  object
#  4   currency          148015 non-null  object
#  5   deadline          148015 non-null  object
#  6   goal              148015 non-null  float64
#  7   launched          148015 non-null  object
#  8   pledged           148015 non-null  float64
#  9   state             148015 non-null  object
#  10  backers           148015 non-null  float64
#  11  country           148015 non-null  object
#  12  usd_pledged       148015 non-null  float64
#  13  usd_pledged_real  148015 non-null  float64
# dtypes: float64(5), int64(1), object(8)
# memory usage: 16.9+ MB

# %%
df_ks
# Out:
#                 ID                                               name  \
# 0        872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1       1326492673                                    Ohceola jewelry
# 2       1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3        156812982  SketchPlanner: Create and Plan- all in one bea...
# 4       1835968190    Proven sales with custom motorcycle accessories
# ...            ...                                                ...
# 149995   574841011  Scutes Headphones - A new way to listen to you...
# 149996   235190237                               My Drunk @$$ Reviews
# 149997   758540498          Freedom Planet - High Speed Platform Game
# 149998  1624952469                                      Clown vs Mime
# 149999   891117261                            Striker's Cafe & Bakery
#
#               category main_category currency    deadline     goal  \
# 0                 Rock         Music      USD  2011-09-16   2000.0
# 1              Fashion       Fashion      USD  2012-08-22  18000.0
# 2       Tabletop Games         Games      USD  2016-07-19   2000.0
# 3            Art Books    Publishing      USD  2017-09-27  13000.0
# 4            Sculpture           Art      CAD  2016-02-24   5000.0
# ...                ...           ...      ...         ...      ...
# 149995  Product Design        Design      USD  2014-11-14  40000.0
# 149996       Webseries  Film & Video      USD  2012-05-18   1000.0
# 149997     Video Games         Games      USD  2013-02-15   2000.0
# 149998       Webseries  Film & Video      USD  2011-05-27   1000.0
# 149999     Food Trucks          Food      USD  2016-05-02  20000.0
#
#                    launched   pledged       state  backers country  \
# 0       2011-08-17 06:31:31   1145.00    canceled     24.0      US
# 1       2012-07-23 20:46:48   1851.00      failed     28.0      US
# 2       2016-07-01 21:55:54   7534.00  successful    254.0      US
# 3       2017-08-28 15:47:02  16298.00  successful    367.0      US
# 4       2016-01-25 17:37:10      1.00      failed      1.0      CA
# ...                     ...       ...         ...      ...     ...
# 149995  2014-10-14 20:44:37   3664.00    canceled     43.0      US
# 149996  2012-04-18 04:42:47      0.00      failed      0.0      US
# 149997  2013-01-16 00:53:32  25472.69  successful   1105.0      US
# 149998  2011-04-27 01:22:52     76.00      failed      3.0      US
# 149999  2016-04-03 08:01:57     29.00      failed      3.0      US
#
#          usd_pledged  usd_pledged_real
# 0        1145.000000       1145.000000
# 1        1851.000000       1851.000000
# 2        3796.000000       7534.000000
# 3        2670.000000      16298.000000
# 4           0.708148          0.738225
# ...              ...               ...
# 149995   3664.000000       3664.000000
# 149996      0.000000          0.000000
# 149997  25472.690000      25472.690000
# 149998     76.000000         76.000000
# 149999     29.000000         29.000000
#
# [148015 rows x 14 columns]

# %%
dtypeCount = [df_ks.iloc[:,i].apply(type).value_counts() for i in range(df_ks.shape[1])]

# %%
dtypeCount
# Out:
# [<class 'int'>    148015
#  Name: ID, dtype: int64, <class 'str'>    148015
#  Name: name, dtype: int64, <class 'str'>    148015
#  Name: category, dtype: int64, <class 'str'>    148015
#  Name: main_category, dtype: int64, <class 'str'>    148015
#  Name: currency, dtype: int64, <class 'str'>    148015
#  Name: deadline, dtype: int64, <class 'float'>    148015
#  Name: goal, dtype: int64, <class 'str'>    148015
#  Name: launched, dtype: int64, <class 'float'>    148015
#  Name: pledged, dtype: int64, <class 'str'>    148015
#  Name: state, dtype: int64, <class 'float'>    148015
#  Name: backers, dtype: int64, <class 'str'>    148015
#  Name: country, dtype: int64, <class 'float'>    148015
#  Name: usd_pledged, dtype: int64, <class 'float'>    148015
#  Name: usd_pledged_real, dtype: int64]

# %% [markdown]
# ### Importer les données

# %%
df_ks_dict = df_ks.to_dict('records')

# %%
df_ks_dict
# Out:
# [{'ID': 872782264,
#   'name': 'Scott Cooper\'s Solo CD "A Leg Trick" (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-09-16',
#   'goal': 2000.0,
#   'launched': '2011-08-17 06:31:31',
#   'pledged': 1145.0,
#   'state': 'canceled',
#   'backers': 24.0,
#   'country': 'US',
#   'usd_pledged': 1145.0,
#   'usd_pledged_real': 1145.0},
#  {'ID': 1326492673,
#   'name': 'Ohceola jewelry',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-08-22',
#   'goal': 18000.0,
#   'launched': '2012-07-23 20:46:48',
#   'pledged': 1851.0,
#   'state': 'failed',
#   'backers': 28.0,
#   'country': 'US',
#   'usd_pledged': 1851.0,
#   'usd_pledged_real': 1851.0},
#  {'ID': 1688410639,
#   'name': 'Sluff Off & Harald: Two latest EGGs are Classics "old & new"',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-19',
#   'goal': 2000.0,
#   'launched': '2016-07-01 21:55:54',
#   'pledged': 7534.0,
#   'state': 'successful',
#   'backers': 254.0,
#   'country': 'US',
#   'usd_pledged': 3796.0,
#   'usd_pledged_real': 7534.0},
#  {'ID': 156812982,
#   'name': 'SketchPlanner: Create and Plan- all in one beautiful book!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-09-27',
#   'goal': 13000.0,
#   'launched': '2017-08-28 15:47:02',
#   'pledged': 16298.0,
#   'state': 'successful',
#   'backers': 367.0,
#   'country': 'US',
#   'usd_pledged': 2670.0,
#   'usd_pledged_real': 16298.0},
#  {'ID': 1835968190,
#   'name': 'Proven sales with custom motorcycle accessories',
#   'category': 'Sculpture',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-02-24',
#   'goal': 5000.0,
#   'launched': '2016-01-25 17:37:10',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'CA',
#   'usd_pledged': 0.70814759,
#   'usd_pledged_real': 0.7382253063635021},
#  {'ID': 1771789139,
#   'name': 'Room For Growth!',
#   'category': 'Couture',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-05-02',
#   'goal': 2000.0,
#   'launched': '2016-04-11 18:15:00',
#   'pledged': 6.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 6.0,
#   'usd_pledged_real': 6.0},
#  {'ID': 1301627822,
#   'name': 'Build a mini Udemy with Laravel and Vuejs',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2018-01-11',
#   'goal': 3000.0,
#   'launched': '2017-12-12 01:37:26',
#   'pledged': 155.0,
#   'state': 'live',
#   'backers': 7.0,
#   'country': 'CA',
#   'usd_pledged': 15.5639964,
#   'usd_pledged_real': 123.81180605479669},
#  {'ID': 881336601,
#   'name': 'Applitizer',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-08-20',
#   'goal': 100000.0,
#   'launched': '2017-07-21 16:50:05',
#   'pledged': 1000.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'HK',
#   'usd_pledged': 128.08538,
#   'usd_pledged_real': 127.83146699391523},
#  {'ID': 1669374237,
#   'name': 'Help I Am Wolves fund their first album "ABCD" on 12" vinyl!',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'EUR',
#   'deadline': '2017-12-04',
#   'goal': 1000.0,
#   'launched': '2017-10-27 16:55:47',
#   'pledged': 1465.0,
#   'state': 'successful',
#   'backers': 46.0,
#   'country': 'BE',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1720.2104175473205},
#  {'ID': 556821416,
#   'name': 'Eco  Bamboo Underwear funding....GOT WOOD ?',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'GBP',
#   'deadline': '2012-12-13',
#   'goal': 9500.0,
#   'launched': '2012-11-13 10:58:34',
#   'pledged': 1212.0,
#   'state': 'failed',
#   'backers': 43.0,
#   'country': 'GB',
#   'usd_pledged': 1928.13711852,
#   'usd_pledged_real': 1953.6728081628705},
#  {'ID': 160394496,
#   'name': 'SHAKTI: The Power of Woman',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-03-13',
#   'goal': 15000.0,
#   'launched': '2012-01-13 16:27:16',
#   'pledged': 18361.89,
#   'state': 'successful',
#   'backers': 126.0,
#   'country': 'US',
#   'usd_pledged': 18361.89,
#   'usd_pledged_real': 18361.89},
#  {'ID': 1248488072,
#   'name': 'Coast to Coaster',
#   'category': 'Print',
#   'main_category': 'Journalism',
#   'currency': 'USD',
#   'deadline': '2017-06-21',
#   'goal': 25000.0,
#   'launched': '2017-05-07 06:05:42',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'ID': 895565490,
#   'name': 'Frostbite Gaming - Minecraft HUB',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2014-11-26',
#   'goal': 400.0,
#   'launched': '2014-10-17 11:25:49',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd_pledged': 15.9921958,
#   'usd_pledged_real': 15.695876693192696},
#  {'ID': 1165822076,
#   'name': 'Support Ramsort album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'NOK',
#   'deadline': '2015-05-03',
#   'goal': 150000.0,
#   'launched': '2015-04-03 14:24:19',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'NO',
#   'usd_pledged': 1.2455610000000001,
#   'usd_pledged_real': 1.3387776959635849},
#  {'ID': 424612381,
#   'name': 'Red No. 95 Issue 3',
#   'category': 'Comic Books',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2017-08-10',
#   'goal': 800.0,
#   'launched': '2017-07-11 08:16:21',
#   'pledged': 955.0,
#   'state': 'successful',
#   'backers': 34.0,
#   'country': 'US',
#   'usd_pledged': 35.0,
#   'usd_pledged_real': 955.0},
#  {'ID': 1182908609,
#   'name': 'Alice In Wonderland!',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2012-06-15',
#   'goal': 220.0,
#   'launched': '2012-05-16 05:37:08',
#   'pledged': 320.0,
#   'state': 'successful',
#   'backers': 13.0,
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'ID': 206040356,
#   'name': 'Un piano : 150 Pas',
#   'category': 'Performances',
#   'main_category': 'Dance',
#   'currency': 'CAD',
#   'deadline': '2017-09-03',
#   'goal': 1500.0,
#   'launched': '2017-07-05 21:52:43',
#   'pledged': 1540.0,
#   'state': 'successful',
#   'backers': 31.0,
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1274.0961363448332},
#  {'ID': 396454289,
#   'name': 'Operation Penumbra: A WWII Supernatural Adventure, Vol. 1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2014-01-17',
#   'goal': 15000.0,
#   'launched': '2013-12-18 23:19:02',
#   'pledged': 5035.0,
#   'state': 'failed',
#   'backers': 81.0,
#   'country': 'US',
#   'usd_pledged': 5035.0,
#   'usd_pledged_real': 5035.0},
#  {'ID': 1522195027,
#   'name': 'Emma Rae',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-07-27',
#   'goal': 12000.0,
#   'launched': '2017-06-27 18:00:25',
#   'pledged': 13415.0,
#   'state': 'successful',
#   'backers': 100.0,
#   'country': 'US',
#   'usd_pledged': 1750.0,
#   'usd_pledged_real': 13415.0},
#  {'ID': 1429288669,
#   'name': 'Strange Occurrences: Performances for Non-Theater Spaces',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2010-09-22',
#   'goal': 3000.0,
#   'launched': '2010-07-23 23:30:10',
#   'pledged': 3080.98,
#   'state': 'successful',
#   'backers': 59.0,
#   'country': 'US',
#   'usd_pledged': 3080.98,
#   'usd_pledged_real': 3080.98},
#  {'ID': 1441999253,
#   'name': 'Ancient Ruins II Base Series',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-11-06',
#   'goal': 1800.0,
#   'launched': '2014-10-22 14:58:46',
#   'pledged': 5630.95,
#   'state': 'successful',
#   'backers': 88.0,
#   'country': 'US',
#   'usd_pledged': 5630.95,
#   'usd_pledged_real': 5630.95},
#  {'ID': 1202442815,
#   'name': 'The Craziest Thing Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-03-22',
#   'goal': 30000.0,
#   'launched': '2014-01-22 00:13:15',
#   'pledged': 300.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 300.0,
#   'usd_pledged_real': 300.0},
#  {'ID': 2116917173,
#   'name': 'Look UP! To this nice shirt!',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2012-11-10',
#   'goal': 3700.0,
#   'launched': '2012-09-26 06:15:44',
#   'pledged': 203.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd_pledged': 203.0,
#   'usd_pledged_real': 203.0},
#  {'ID': 2117684680,
#   'name': 'Ghost Nest: Giving the Power of Design Back to the Consumer (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2010-11-17',
#   'goal': 18729.0,
#   'launched': '2010-10-08 01:29:29',
#   'pledged': 1781.0,
#   'state': 'canceled',
#   'backers': 32.0,
#   'country': 'US',
#   'usd_pledged': 1781.0,
#   'usd_pledged_real': 1781.0},
#  {'ID': 350628546,
#   'name': 'Elli (Canceled)',
#   'category': 'Crafts',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2014-11-03',
#   'goal': 5000.0,
#   'launched': '2014-09-04 00:10:14',
#   'pledged': 121.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'ID': 35969505,
#   'name': 'States, Firms, & Households: the search for equilibrium (2)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-01-22',
#   'goal': 100.0,
#   'launched': '2015-12-23 07:35:24',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1849047042,
#   'name': "Central Florida Artisans' Guild: Community Growth",
#   'category': 'DIY',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2015-05-12',
#   'goal': 2000.0,
#   'launched': '2015-04-22 18:59:35',
#   'pledged': 121.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd_pledged': 121.0,
#   'usd_pledged_real': 121.0},
#  {'ID': 295864582,
#   'name': 'Frankenstein Soft Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-09-29',
#   'goal': 215.0,
#   'launched': '2017-09-22 22:25:58',
#   'pledged': 18.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 18.0},
#  {'ID': 496463082,
#   'name': 'qualMeter XT: Greater Experience on Cable/Charger Testing',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2017-06-05',
#   'goal': 5000.0,
#   'launched': '2017-05-06 15:13:17',
#   'pledged': 10655.0,
#   'state': 'successful',
#   'backers': 222.0,
#   'country': 'CA',
#   'usd_pledged': 5300.34825892,
#   'usd_pledged_real': 7887.334369679473},
#  {'ID': 1390262683,
#   'name': 'Candy Coburn - "THE GOOD LIFE" New Soul Rockin\' Studio Album',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2016-06-08',
#   'goal': 15000.0,
#   'launched': '2016-05-10 12:43:24',
#   'pledged': 15530.0,
#   'state': 'successful',
#   'backers': 151.0,
#   'country': 'US',
#   'usd_pledged': 15530.0,
#   'usd_pledged_real': 15530.0},
#  {'ID': 1041882251,
#   'name': "Gentlemen's Bar",
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 4000.0,
#   'launched': '2016-06-16 20:31:11',
#   'pledged': 613.0,
#   'state': 'failed',
#   'backers': 25.0,
#   'country': 'US',
#   'usd_pledged': 433.0,
#   'usd_pledged_real': 613.0},
#  {'ID': 1130940376,
#   'name': 'A Sickle Life',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-01',
#   'goal': 5000.0,
#   'launched': '2016-06-01 15:15:40',
#   'pledged': 60.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 60.0,
#   'usd_pledged_real': 60.0},
#  {'ID': 186326896,
#   'name': 'NYC Type',
#   'category': 'Software',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2012-10-30',
#   'goal': 10000.0,
#   'launched': '2012-10-11 00:28:31',
#   'pledged': 10106.0,
#   'state': 'successful',
#   'backers': 179.0,
#   'country': 'US',
#   'usd_pledged': 10106.0,
#   'usd_pledged_real': 10106.0},
#  {'ID': 1025722498,
#   'name': 'PatentSlice.com-Automated Patent Drill-Down & Analysis Tool',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-03-23',
#   'goal': 5000.0,
#   'launched': '2017-02-21 21:37:27',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1493170888,
#   'name': 'The Birdsongs - New CD Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-04-28',
#   'goal': 5000.0,
#   'launched': '2011-03-18 02:50:18',
#   'pledged': 6357.0,
#   'state': 'successful',
#   'backers': 83.0,
#   'country': 'US',
#   'usd_pledged': 6357.0,
#   'usd_pledged_real': 6357.0},
#  {'ID': 1007463174,
#   'name': 'Brazilian pop artist Kiko London Tour support',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-04-17',
#   'goal': 8000.0,
#   'launched': '2017-03-14 19:22:11',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1.0},
#  {'ID': 2143760539,
#   'name': 'Emissary - Tabletop RPG',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2016-03-21',
#   'goal': 5000.0,
#   'launched': '2016-02-20 15:46:23',
#   'pledged': 9324.0,
#   'state': 'successful',
#   'backers': 334.0,
#   'country': 'GB',
#   'usd_pledged': 13350.07578744,
#   'usd_pledged_real': 13174.888019103872},
#  {'ID': 2062002375,
#   'name': 'Desktop Museum of Card Art',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-04-11',
#   'goal': 1600.0,
#   'launched': '2014-03-12 22:33:56',
#   'pledged': 587.0,
#   'state': 'failed',
#   'backers': 28.0,
#   'country': 'US',
#   'usd_pledged': 587.0,
#   'usd_pledged_real': 587.0},
#  {'ID': 1183084584,
#   'name': 'Act for Change: Healing Minds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2014-08-13',
#   'goal': 16000.0,
#   'launched': '2014-07-14 22:47:13',
#   'pledged': 1638.0,
#   'state': 'failed',
#   'backers': 38.0,
#   'country': 'GB',
#   'usd_pledged': 2804.4439605000002,
#   'usd_pledged_real': 2733.827358301622},
#  {'ID': 1977195934,
#   'name': 'Book: Outrageously (un)loved - The fight against selfhatred',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'EUR',
#   'deadline': '2015-03-30',
#   'goal': 900.0,
#   'launched': '2015-01-29 23:17:48',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'NL',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1035882318,
#   'name': 'Help match our 2nd NEA grant for Glory Denied',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-11-12',
#   'goal': 2500.0,
#   'launched': '2015-10-26 14:06:42',
#   'pledged': 2650.0,
#   'state': 'successful',
#   'backers': 29.0,
#   'country': 'US',
#   'usd_pledged': 2650.0,
#   'usd_pledged_real': 2650.0},
#  {'ID': 1021441525,
#   'name': 'The Alchemy of Art Book',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'CAD',
#   'deadline': '2016-12-22',
#   'goal': 7770.0,
#   'launched': '2016-11-28 02:06:47',
#   'pledged': 25.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 18.499334023975138},
#  {'ID': 1691723287,
#   'name': 'The Om Space',
#   'category': 'Civic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-08',
#   'goal': 15000.0,
#   'launched': '2016-06-08 18:13:45',
#   'pledged': 1512.0,
#   'state': 'failed',
#   'backers': 28.0,
#   'country': 'US',
#   'usd_pledged': 1512.0,
#   'usd_pledged_real': 1512.0},
#  {'ID': 680665134,
#   'name': 'Open Source Gemini Simulator',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-17',
#   'goal': 1675.0,
#   'launched': '2017-07-18 19:37:33',
#   'pledged': 1685.0,
#   'state': 'successful',
#   'backers': 28.0,
#   'country': 'US',
#   'usd_pledged': 135.0,
#   'usd_pledged_real': 1685.0},
#  {'ID': 1864901261,
#   'name': 'Tenabris Ides',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-14',
#   'goal': 1500.0,
#   'launched': '2015-02-14 03:53:39',
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 16.0,
#   'usd_pledged_real': 16.0},
#  {'ID': 519449839,
#   'name': 'Johnny P - Resurrected (Album)',
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-07',
#   'goal': 750.0,
#   'launched': '2013-07-08 22:54:55',
#   'pledged': 26.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 26.0,
#   'usd_pledged_real': 26.0},
#  {'ID': 1875047349,
#   'name': 'Hope for our youth today',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-08-20',
#   'goal': 6700.0,
#   'launched': '2014-07-21 20:03:14',
#   'pledged': 13.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 13.0,
#   'usd_pledged_real': 13.0},
#  {'ID': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 75000.0,
#   'launched': '2014-10-15 06:34:48',
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'backers': 10293.0,
#   'country': 'US',
#   'usd_pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'ID': 1263082934,
#   'name': 'STEAM for Students',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-14',
#   'goal': 5000.0,
#   'launched': '2014-08-15 04:46:08',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'ID': 764437823,
#   'name': 'Cold Waters, Warm Hearts: Portraits of Women Who Fly-Fish',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-06-28',
#   'goal': 10000.0,
#   'launched': '2016-05-19 02:48:20',
#   'pledged': 586.0,
#   'state': 'failed',
#   'backers': 15.0,
#   'country': 'US',
#   'usd_pledged': 586.0,
#   'usd_pledged_real': 586.0},
#  {'ID': 1341393677,
#   'name': 'Sure Set Hook',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-15',
#   'goal': 15000.0,
#   'launched': '2014-12-16 15:43:20',
#   'pledged': 100.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 100.0},
#  {'ID': 1149469807,
#   'name': 'Bespoke by Demian Custom Menswear',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 10000.0,
#   'launched': '2015-08-11 21:43:39',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1968352897,
#   'name': 'Renewable Soy + American Made Candles = LOVE',
#   'category': 'Candles',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2012-02-23',
#   'goal': 1000.0,
#   'launched': '2012-01-24 02:19:34',
#   'pledged': 2325.0,
#   'state': 'successful',
#   'backers': 39.0,
#   'country': 'US',
#   'usd_pledged': 2325.0,
#   'usd_pledged_real': 2325.0},
#  {'ID': 693501911,
#   'name': 'Spray Art on canvas series',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'GBP',
#   'deadline': '2015-05-14',
#   'goal': 5000.0,
#   'launched': '2015-04-14 13:33:36',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 397524601,
#   'name': "Make Rubulad's Dream Home Come True",
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-12-09',
#   'goal': 35000.0,
#   'launched': '2011-11-11 18:49:35',
#   'pledged': 37248.52,
#   'state': 'successful',
#   'backers': 733.0,
#   'country': 'US',
#   'usd_pledged': 37248.52,
#   'usd_pledged_real': 37248.52},
#  {'ID': 520797301,
#   'name': 'Bad Habit Beers',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-10-17',
#   'goal': 25000.0,
#   'launched': '2015-09-17 21:35:33',
#   'pledged': 7522.0,
#   'state': 'failed',
#   'backers': 76.0,
#   'country': 'US',
#   'usd_pledged': 7522.0,
#   'usd_pledged_real': 7522.0},
#  {'ID': 1195741430,
#   'name': 'Bring the BBBC home for Christmas (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-10-20',
#   'goal': 55000.0,
#   'launched': '2014-09-25 17:04:11',
#   'pledged': 1395.0,
#   'state': 'canceled',
#   'backers': 14.0,
#   'country': 'US',
#   'usd_pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'ID': 2024072867,
#   'name': 'Black Lotus Empire-issue #1',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-09-23',
#   'goal': 2500.0,
#   'launched': '2012-08-14 18:25:36',
#   'pledged': 3905.51,
#   'state': 'successful',
#   'backers': 195.0,
#   'country': 'US',
#   'usd_pledged': 3905.51,
#   'usd_pledged_real': 3905.51},
#  {'ID': 223758456,
#   'name': 'Toasty the Magic Fireplace',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-10-20',
#   'goal': 10000.0,
#   'launched': '2017-09-20 18:04:19',
#   'pledged': 33.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 33.0},
#  {'ID': 1594750207,
#   'name': 'Lake Forest Drone',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2016-04-14',
#   'goal': 875.0,
#   'launched': '2016-03-05 18:11:17',
#   'pledged': 103.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 103.0,
#   'usd_pledged_real': 103.0},
#  {'ID': 726485587,
#   'name': 'The Meadow Project',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-02-20',
#   'goal': 20000.0,
#   'launched': '2012-01-07 17:39:58',
#   'pledged': 21635.0,
#   'state': 'successful',
#   'backers': 290.0,
#   'country': 'US',
#   'usd_pledged': 21635.0,
#   'usd_pledged_real': 21635.0},
#  {'ID': 260647442,
#   'name': 'Clash in the Caucuses 2016',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-13',
#   'goal': 17500.0,
#   'launched': '2016-10-14 02:44:13',
#   'pledged': 682.0,
#   'state': 'failed',
#   'backers': 15.0,
#   'country': 'US',
#   'usd_pledged': 86.0,
#   'usd_pledged_real': 682.0},
#  {'ID': 1043191090,
#   'name': 'Politics with Allies',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-25',
#   'goal': 20000.0,
#   'launched': '2017-03-21 18:05:36',
#   'pledged': 554.0,
#   'state': 'failed',
#   'backers': 23.0,
#   'country': 'US',
#   'usd_pledged': 127.0,
#   'usd_pledged_real': 554.0},
#  {'ID': 395755489,
#   'name': 'Kawaii Heroes Soft Enamel Pins | Stickers | Commissions',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-12-03',
#   'goal': 800.0,
#   'launched': '2017-11-03 19:38:21',
#   'pledged': 23.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 23.0,
#   'usd_pledged_real': 23.0},
#  {'ID': 830800632,
#   'name': 'Martin Game Studios',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-11-01',
#   'goal': 5000.0,
#   'launched': '2014-10-02 18:10:05',
#   'pledged': 3.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 3.0,
#   'usd_pledged_real': 3.0},
#  {'ID': 2113778157,
#   'name': 'Air Basketball',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 1500.0,
#   'launched': '2013-11-08 03:02:49',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 163783398,
#   'name': 'ZERUBA',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-02-24',
#   'goal': 1000.0,
#   'launched': '2015-01-25 02:21:51',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 2.0,
#   'usd_pledged_real': 2.0},
#  {'ID': 2069080555,
#   'name': 'Crashpads and Paddles: A Rock climbing adventure by canoe',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'CAD',
#   'deadline': '2015-06-06',
#   'goal': 1500.0,
#   'launched': '2015-05-05 20:37:22',
#   'pledged': 80.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'CA',
#   'usd_pledged': 65.7148416,
#   'usd_pledged_real': 65.02479070145492},
#  {'ID': 1224888533,
#   'name': 'Eating Up Easter - Finishing Funds',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-06-09',
#   'goal': 30000.0,
#   'launched': '2017-05-10 16:22:26',
#   'pledged': 35182.0,
#   'state': 'successful',
#   'backers': 249.0,
#   'country': 'US',
#   'usd_pledged': 4215.0,
#   'usd_pledged_real': 35182.0},
#  {'ID': 1841566953,
#   'name': 'Clocks Cameras Computers & Murder:  What Else Can Go Wrong?',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-05-19',
#   'goal': 6000.0,
#   'launched': '2015-04-19 20:03:18',
#   'pledged': 900.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd_pledged': 900.0,
#   'usd_pledged_real': 900.0},
#  {'ID': 449615827,
#   'name': 'High Caliber Community (HC2); a place for veteran networking',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-19',
#   'goal': 75000.0,
#   'launched': '2017-11-19 21:37:19',
#   'pledged': 4196.0,
#   'state': 'failed',
#   'backers': 30.0,
#   'country': 'US',
#   'usd_pledged': 1876.0,
#   'usd_pledged_real': 4196.0},
#  {'ID': 442102012,
#   'name': "Rudely Stamp'd Historical Impressions",
#   'category': 'Plays',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2017-12-26',
#   'goal': 6000.0,
#   'launched': '2017-10-27 05:04:26',
#   'pledged': 550.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'US',
#   'usd_pledged': 100.0,
#   'usd_pledged_real': 550.0},
#  {'ID': 1054276073,
#   'name': '(Teacher) Documentary, Jack teaches Buddhist Monks English',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-09-01',
#   'goal': 2390.0,
#   'launched': '2016-07-28 16:34:56',
#   'pledged': 2773.0,
#   'state': 'successful',
#   'backers': 43.0,
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 2773.0},
#  {'ID': 1292948737,
#   'name': 'Tarot eCards App: Tarot Reading App for mobile devices',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-01-13',
#   'goal': 12000.0,
#   'launched': '2013-12-09 13:51:59',
#   'pledged': 796.66,
#   'state': 'failed',
#   'backers': 29.0,
#   'country': 'US',
#   'usd_pledged': 796.66,
#   'usd_pledged_real': 796.66},
#  {'ID': 2036356057,
#   'name': 'Sound is Revolution',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2017-05-23',
#   'goal': 50000.0,
#   'launched': '2017-04-23 22:07:56',
#   'pledged': 11.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 14.125019261389902},
#  {'ID': 56346579,
#   'name': 'City of the Shroud',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-05-06',
#   'goal': 14000.0,
#   'launched': '2016-04-06 18:00:04',
#   'pledged': 16239.0,
#   'state': 'successful',
#   'backers': 302.0,
#   'country': 'US',
#   'usd_pledged': 16239.0,
#   'usd_pledged_real': 16239.0},
#  {'ID': 797794426,
#   'name': "Skunk Rider's first album",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-05-16',
#   'goal': 500.0,
#   'launched': '2015-05-01 17:31:59',
#   'pledged': 1395.0,
#   'state': 'successful',
#   'backers': 14.0,
#   'country': 'US',
#   'usd_pledged': 1395.0,
#   'usd_pledged_real': 1395.0},
#  {'ID': 1086953170,
#   'name': "'Jamie and Friends' - Greeting Cards",
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'currency': 'GBP',
#   'deadline': '2015-07-25',
#   'goal': 1000.0,
#   'launched': '2015-06-25 18:58:28',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd_pledged': 31.478563800000003,
#   'usd_pledged_real': 31.15167751783433},
#  {'ID': 955493948,
#   'name': 'W.E.T West End Terminal: Outdoor Chair Show/Art Installation',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-06-20',
#   'goal': 8500.0,
#   'launched': '2011-05-04 02:51:56',
#   'pledged': 8644.0,
#   'state': 'successful',
#   'backers': 47.0,
#   'country': 'US',
#   'usd_pledged': 8644.0,
#   'usd_pledged_real': 8644.0},
#  {'ID': 133917405,
#   'name': 'BrainScrambler',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-05-04',
#   'goal': 8000.0,
#   'launched': '2012-04-04 21:26:16',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1702541310,
#   'name': 'Paint Ring',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-06-24',
#   'goal': 55000.0,
#   'launched': '2017-05-15 19:52:07',
#   'pledged': 2.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 2.0},
#  {'ID': 87518909,
#   'name': 'Just Rock Showcase and Songwriter Circle 2014 at the studio',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-12-31',
#   'goal': 1500.0,
#   'launched': '2013-11-15 17:38:39',
#   'pledged': 2180.0,
#   'state': 'successful',
#   'backers': 14.0,
#   'country': 'US',
#   'usd_pledged': 2180.0,
#   'usd_pledged_real': 2180.0},
#  {'ID': 1957326840,
#   'name': 'BRIGADE RETURNS!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-06-15',
#   'goal': 17500.0,
#   'launched': '2013-05-16 21:24:04',
#   'pledged': 35343.0,
#   'state': 'successful',
#   'backers': 562.0,
#   'country': 'US',
#   'usd_pledged': 35343.0,
#   'usd_pledged_real': 35343.0},
#  {'ID': 1593966557,
#   'name': 'Red Box Games Dwarves, and Goblins, and Orcs Oh MY!!',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-06-16',
#   'goal': 5000.0,
#   'launched': '2013-05-19 21:49:38',
#   'pledged': 39258.0,
#   'state': 'successful',
#   'backers': 269.0,
#   'country': 'US',
#   'usd_pledged': 39258.0,
#   'usd_pledged_real': 39258.0},
#  {'ID': 1029624752,
#   'name': 'Doodle Art to Color Returns!',
#   'category': 'Art Books',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2014-06-29',
#   'goal': 25.0,
#   'launched': '2014-06-14 18:50:10',
#   'pledged': 25.5,
#   'state': 'successful',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 25.5,
#   'usd_pledged_real': 25.5},
#  {'ID': 888065158,
#   'name': 'New Patent Design Pocket Sheet+',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-17',
#   'goal': 25000.0,
#   'launched': '2015-06-18 23:21:20',
#   'pledged': 190.0,
#   'state': 'failed',
#   'backers': 5.0,
#   'country': 'US',
#   'usd_pledged': 190.0,
#   'usd_pledged_real': 190.0},
#  {'ID': 14239768,
#   'name': 'What I Did Today',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-17',
#   'goal': 5000.0,
#   'launched': '2012-08-16 00:00:27',
#   'pledged': 360.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'US',
#   'usd_pledged': 360.0,
#   'usd_pledged_real': 360.0},
#  {'ID': 1890385189,
#   'name': 'The Falling Girl- Chronicles of the Closed World, Book 1',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-04-09',
#   'goal': 500.0,
#   'launched': '2012-03-10 01:37:26',
#   'pledged': 695.0,
#   'state': 'successful',
#   'backers': 9.0,
#   'country': 'US',
#   'usd_pledged': 695.0,
#   'usd_pledged_real': 695.0},
#  {'ID': 368889340,
#   'name': '"Intermittent Polarity" Art book by Brent and Kayla Woodside',
#   'category': 'Illustration',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-08-12',
#   'goal': 1000.0,
#   'launched': '2012-07-13 03:32:53',
#   'pledged': 610.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd_pledged': 610.0,
#   'usd_pledged_real': 610.0},
#  {'ID': 671724371,
#   'name': 'The Dark Lord and the Seamstress',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'CAD',
#   'deadline': '2014-09-14',
#   'goal': 5000.0,
#   'launched': '2014-08-11 21:02:05',
#   'pledged': 5336.0,
#   'state': 'successful',
#   'backers': 99.0,
#   'country': 'CA',
#   'usd_pledged': 4862.92048512,
#   'usd_pledged_real': 4860.630351612315},
#  {'ID': 231038205,
#   'name': "Towering Trees' First Album!",
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-11',
#   'goal': 2250.0,
#   'launched': '2013-07-12 21:23:16',
#   'pledged': 2267.0,
#   'state': 'successful',
#   'backers': 66.0,
#   'country': 'US',
#   'usd_pledged': 2267.0,
#   'usd_pledged_real': 2267.0},
#  {'ID': 673468258,
#   'name': 'Daybook notebooks (Canceled)',
#   'category': 'Stationery',
#   'main_category': 'Crafts',
#   'currency': 'USD',
#   'deadline': '2016-02-25',
#   'goal': 1000.0,
#   'launched': '2016-01-26 06:29:43',
#   'pledged': 52.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 52.0,
#   'usd_pledged_real': 52.0},
#  {'ID': 765608919,
#   'name': 'Big Barbeque',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-04',
#   'goal': 20000.0,
#   'launched': '2014-09-04 15:25:21',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1451163055,
#   'name': 'iKlimt App: The Life & Work of Gustav Klimt',
#   'category': 'Digital Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-02-11',
#   'goal': 5000.0,
#   'launched': '2012-01-12 07:17:54',
#   'pledged': 66.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd_pledged': 66.0,
#   'usd_pledged_real': 66.0},
#  {'ID': 523925424,
#   'name': 'Seasons in the Sanctuary',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-10-02',
#   'goal': 4000.0,
#   'launched': '2012-09-07 21:56:47',
#   'pledged': 4808.0,
#   'state': 'successful',
#   'backers': 101.0,
#   'country': 'US',
#   'usd_pledged': 4808.0,
#   'usd_pledged_real': 4808.0},
#  {'ID': 488491938,
#   'name': 'Charlie Chipmink',
#   'category': "Children's Books",
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-06-03',
#   'goal': 35000.0,
#   'launched': '2017-05-04 02:14:23',
#   'pledged': 430.0,
#   'state': 'failed',
#   'backers': 6.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 430.0},
#  {'ID': 899938474,
#   'name': '500 Years Later: An Oral History of Final Fantasy VII',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'GBP',
#   'deadline': '2017-12-10',
#   'goal': 38000.0,
#   'launched': '2017-11-10 14:00:05',
#   'pledged': 72881.0,
#   'state': 'successful',
#   'backers': 1871.0,
#   'country': 'GB',
#   'usd_pledged': 52551.44488998,
#   'usd_pledged_real': 97495.75267882225},
#  {'ID': 870077018,
#   'name': 'Take every shower with Matt Gator and stop shower mat mold',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-06-08',
#   'goal': 34000.0,
#   'launched': '2017-05-10 07:49:12',
#   'pledged': 21.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 21.0},
#  {'ID': 1564568013,
#   'name': 'The VDown Podcast Intro (Canceled)',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-10-03',
#   'goal': 1100.0,
#   'launched': '2014-09-03 01:45:25',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1010701682,
#   'name': 'XPLUS Watches: Second Release',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'AUD',
#   'deadline': '2015-10-29',
#   'goal': 10000.0,
#   'launched': '2015-09-30 00:56:12',
#   'pledged': 16889.0,
#   'state': 'successful',
#   'backers': 114.0,
#   'country': 'AU',
#   'usd_pledged': 11874.69592693,
#   'usd_pledged_real': 11970.37352044794},
#  {'ID': 1425142887,
#   'name': 'Mathatar - An online Maths adventure game for KS2 to GCSE',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2017-01-12',
#   'goal': 5000.0,
#   'launched': '2016-12-07 18:21:50',
#   'pledged': 369.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'GB',
#   'usd_pledged': 154.21025895,
#   'usd_pledged_real': 449.34242571846085},
#  {'ID': 1843557102,
#   'name': 'Son of a Gun',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-02-26',
#   'goal': 20000.0,
#   'launched': '2011-12-28 17:57:05',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1721659818,
#   'name': 'Bourbon Chicken',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'CAD',
#   'deadline': '2014-08-05',
#   'goal': 30.0,
#   'launched': '2014-07-21 20:36:34',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'CA',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 186346662,
#   'name': 'T-Shirt of the Year',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2011-07-03',
#   'goal': 1700.0,
#   'launched': '2011-04-04 06:35:03',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 619587010,
#   'name': 'Nobody: A Fallout Tale',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-11',
#   'goal': 8200.0,
#   'launched': '2015-11-10 22:37:04',
#   'pledged': 1229.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd_pledged': 1229.0,
#   'usd_pledged_real': 1229.0},
#  {'ID': 831196575,
#   'name': 'The Tower',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2015-08-01',
#   'goal': 50000.0,
#   'launched': '2015-06-22 17:51:49',
#   'pledged': 283.0,
#   'state': 'failed',
#   'backers': 23.0,
#   'country': 'GB',
#   'usd_pledged': 449.38753223,
#   'usd_pledged_real': 439.1273314092417},
#  {'ID': 1517578386,
#   'name': 'AutoDock Car Organizer',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-16',
#   'goal': 50000.0,
#   'launched': '2017-09-01 15:31:27',
#   'pledged': 1775.0,
#   'state': 'failed',
#   'backers': 17.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 1775.0},
#  {'ID': 569529453,
#   'name': 'Let Me Tell You/No Money Down David Pemberton/Sally Phillips',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2015-09-30',
#   'goal': 10000.0,
#   'launched': '2015-08-31 23:19:47',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 639226845,
#   'name': 'Kiss Kiss Missiles',
#   'category': 'Performance Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-03-08',
#   'goal': 4000.0,
#   'launched': '2012-02-03 00:35:06',
#   'pledged': 4075.0,
#   'state': 'successful',
#   'backers': 76.0,
#   'country': 'US',
#   'usd_pledged': 4075.0,
#   'usd_pledged_real': 4075.0},
#  {'ID': 2072974553,
#   'name': 'The Fountain of Light: a luminous juggling machine',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2011-05-20',
#   'goal': 8000.0,
#   'launched': '2011-04-03 05:55:28',
#   'pledged': 8295.36,
#   'state': 'successful',
#   'backers': 124.0,
#   'country': 'US',
#   'usd_pledged': 8295.36,
#   'usd_pledged_real': 8295.36},
#  {'ID': 328543359,
#   'name': 'Dead of Winter',
#   'category': 'Publishing',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-12-10',
#   'goal': 700.0,
#   'launched': '2017-11-22 18:00:03',
#   'pledged': 767.0,
#   'state': 'successful',
#   'backers': 23.0,
#   'country': 'US',
#   'usd_pledged': 226.0,
#   'usd_pledged_real': 767.0},
#  {'ID': 893780456,
#   'name': 'To Nowhere From Nobody: An Open Source Music Project',
#   'category': 'Pop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2012-11-09',
#   'goal': 2500.0,
#   'launched': '2012-10-20 15:14:49',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'ID': 1771281327,
#   'name': 'Swiss Producer Battle (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'CHF',
#   'deadline': '2015-08-16',
#   'goal': 20000.0,
#   'launched': '2015-07-10 20:55:47',
#   'pledged': 175.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'CH',
#   'usd_pledged': 185.09312849999998,
#   'usd_pledged_real': 183.3881751304676},
#  {'ID': 1840068470,
#   'name': 'Diamond by Stay high clothing',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'AUD',
#   'deadline': '2016-08-01',
#   'goal': 2000.0,
#   'launched': '2016-07-11 17:28:19',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'AU',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 933275417,
#   'name': 'Fruition of FORMS OF IDENTIFICATION',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-12-16',
#   'goal': 2000.0,
#   'launched': '2010-10-15 00:16:02',
#   'pledged': 2196.0,
#   'state': 'successful',
#   'backers': 44.0,
#   'country': 'US',
#   'usd_pledged': 2196.0,
#   'usd_pledged_real': 2196.0},
#  {'ID': 1612333257,
#   'name': 'CUSTOM PET PORTRAIT IN 3 STYLES ( Cat / Dog / all animals! )',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'HKD',
#   'deadline': '2017-04-14',
#   'goal': 800.0,
#   'launched': '2017-03-15 03:59:16',
#   'pledged': 1250.0,
#   'state': 'successful',
#   'backers': 3.0,
#   'country': 'HK',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 160.74689437000075},
#  {'ID': 350352717,
#   'name': '"The \'Devil" (Canceled)',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-03-10',
#   'goal': 600.0,
#   'launched': '2013-02-07 19:08:20',
#   'pledged': 320.0,
#   'state': 'canceled',
#   'backers': 11.0,
#   'country': 'US',
#   'usd_pledged': 320.0,
#   'usd_pledged_real': 320.0},
#  {'ID': 358910116,
#   'name': 'Piano Wars: Dueling Piano Competition - TV Pilot Episode',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2011-06-21',
#   'goal': 12500.0,
#   'launched': '2011-04-22 03:01:34',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1509749942,
#   'name': 'Clash Calc (Canceled)',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-08-10',
#   'goal': 200.0,
#   'launched': '2015-07-20 19:05:57',
#   'pledged': 10.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'ID': 256728964,
#   'name': '"Film School Porno" My film school senior project',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2010-10-01',
#   'goal': 2000.0,
#   'launched': '2010-08-17 00:59:19',
#   'pledged': 2038.0,
#   'state': 'successful',
#   'backers': 12.0,
#   'country': 'US',
#   'usd_pledged': 2038.0,
#   'usd_pledged_real': 2038.0},
#  {'ID': 640450615,
#   'name': 'Carry the Tune',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-04-13',
#   'goal': 6000.0,
#   'launched': '2014-03-14 04:43:39',
#   'pledged': 6756.0,
#   'state': 'successful',
#   'backers': 127.0,
#   'country': 'US',
#   'usd_pledged': 6756.0,
#   'usd_pledged_real': 6756.0},
#  {'ID': 7168821,
#   'name': 'FitCraft',
#   'category': 'Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-05-01',
#   'goal': 5000.0,
#   'launched': '2015-03-02 23:00:51',
#   'pledged': 1504.0,
#   'state': 'failed',
#   'backers': 71.0,
#   'country': 'US',
#   'usd_pledged': 1504.0,
#   'usd_pledged_real': 1504.0},
#  {'ID': 727551984,
#   'name': 'Robert Rex Waller Jr "Fancy Free" Solo Covers LP (Pre-Order)',
#   'category': 'Country & Folk',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2016-04-23',
#   'goal': 7000.0,
#   'launched': '2016-03-22 18:46:14',
#   'pledged': 9244.0,
#   'state': 'successful',
#   'backers': 151.0,
#   'country': 'US',
#   'usd_pledged': 9244.0,
#   'usd_pledged_real': 9244.0},
#  {'ID': 757625439,
#   'name': 'SeaGulls',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-06-01',
#   'goal': 8000.0,
#   'launched': '2015-05-02 22:42:38',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'ID': 2012699952,
#   'name': 'iCROS - microscope for your smartphone, tablet or iPod touch',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CHF',
#   'deadline': '2016-11-20',
#   'goal': 20000.0,
#   'launched': '2016-10-18 06:20:52',
#   'pledged': 4293.0,
#   'state': 'failed',
#   'backers': 268.0,
#   'country': 'CH',
#   'usd_pledged': 1501.75625937,
#   'usd_pledged_real': 4235.398579321231},
#  {'ID': 1185745802,
#   'name': 'The Microbrew Project',
#   'category': 'Events',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-10-26',
#   'goal': 15000.0,
#   'launched': '2014-08-27 18:40:21',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1770997012,
#   'name': 'So you want to be an entreprenuer',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-11-28',
#   'goal': 1000.0,
#   'launched': '2014-10-29 16:23:54',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1457582752,
#   'name': 'Zoigl Beer - The New Sheriff in Town (Canceled)',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2015-12-14',
#   'goal': 15000.0,
#   'launched': '2015-11-13 05:52:51',
#   'pledged': 3681.0,
#   'state': 'canceled',
#   'backers': 28.0,
#   'country': 'US',
#   'usd_pledged': 3681.0,
#   'usd_pledged_real': 3681.0},
#  {'ID': 1446627191,
#   'name': 'The Eastern Addition',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-10-16',
#   'goal': 10000.0,
#   'launched': '2012-09-17 05:44:11',
#   'pledged': 11204.0,
#   'state': 'successful',
#   'backers': 195.0,
#   'country': 'US',
#   'usd_pledged': 11204.0,
#   'usd_pledged_real': 11204.0},
#  {'ID': 555087193,
#   'name': 'Christian Short Video and Devotional Series',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-29',
#   'goal': 500.0,
#   'launched': '2012-08-30 04:06:37',
#   'pledged': 5.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 5.0,
#   'usd_pledged_real': 5.0},
#  {'ID': 2012910935,
#   'name': '"Illuminate" - Artwork Album and Film',
#   'category': 'Mixed Media',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-03-07',
#   'goal': 30000.0,
#   'launched': '2015-02-05 02:53:40',
#   'pledged': 86.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 86.0,
#   'usd_pledged_real': 86.0},
#  {'ID': 625077982,
# ...
#   'backers': 34.0,
#   'country': 'US',
#   'usd_pledged': 2532.0,
#   'usd_pledged_real': 2532.0},
#  {'ID': 827535157,
#   'name': 'Cravar ï¿½ Leather Tote Bags (Canceled)',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-22',
#   'goal': 15000.0,
#   'launched': '2015-10-23 16:33:13',
#   'pledged': 6748.0,
#   'state': 'canceled',
#   'backers': 35.0,
#   'country': 'US',
#   'usd_pledged': 6748.0,
#   'usd_pledged_real': 6748.0},
#  {'ID': 1169744690,
#   'name': 'Camper Enamel Pin',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-09-26',
#   'goal': 350.0,
#   'launched': '2017-09-11 17:57:41',
#   'pledged': 379.0,
#   'state': 'successful',
#   'backers': 21.0,
#   'country': 'US',
#   'usd_pledged': 55.0,
#   'usd_pledged_real': 379.0},
#  {'ID': 634066630,
#   'name': "Plug 'N Plunge (Bathtub Overflow Pipe Plug)",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-01',
#   'goal': 2500.0,
#   'launched': '2015-02-02 21:15:46',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 575660043,
#   'name': 'CANCELED (Canceled)',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-09-12',
#   'goal': 33000.0,
#   'launched': '2014-08-10 19:42:03',
#   'pledged': 3649.0,
#   'state': 'canceled',
#   'backers': 17.0,
#   'country': 'US',
#   'usd_pledged': 3649.0,
#   'usd_pledged_real': 3649.0},
#  {'ID': 2067634614,
#   'name': 'Changing the Radio / Production Industry with an iOS Device',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'GBP',
#   'deadline': '2012-12-21',
#   'goal': 500.0,
#   'launched': '2012-11-21 01:18:53',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 1707385269,
#   'name': 'Better Food Control - Less Food Poisoning',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'NOK',
#   'deadline': '2017-04-18',
#   'goal': 200000.0,
#   'launched': '2017-02-17 23:25:04',
#   'pledged': 705.0,
#   'state': 'failed',
#   'backers': 3.0,
#   'country': 'NO',
#   'usd_pledged': 84.043491,
#   'usd_pledged_real': 81.55568923233541},
#  {'ID': 1613602272,
#   'name': 'ROPIX JUMP ROPE SHOES',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-03-30',
#   'goal': 10000.0,
#   'launched': '2014-02-05 05:36:38',
#   'pledged': 10690.0,
#   'state': 'successful',
#   'backers': 117.0,
#   'country': 'US',
#   'usd_pledged': 10690.0,
#   'usd_pledged_real': 10690.0},
#  {'ID': 1109297992,
#   'name': 'Symphony of 1000: Be a part of it!',
#   'category': 'Classical Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2014-01-23',
#   'goal': 4000.0,
#   'launched': '2013-12-24 21:40:33',
#   'pledged': 162.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'US',
#   'usd_pledged': 162.0,
#   'usd_pledged_real': 162.0},
#  {'ID': 142828580,
#   'name': 'THE POWER PRINCIPLE',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-08-24',
#   'goal': 7000.0,
#   'launched': '2012-07-10 12:37:25',
#   'pledged': 7263.0,
#   'state': 'successful',
#   'backers': 189.0,
#   'country': 'US',
#   'usd_pledged': 7263.0,
#   'usd_pledged_real': 7263.0},
#  {'ID': 1109543634,
#   'name': "'AlwaysOn' 5pee (for scale)",
#   'category': 'Fine Art',
#   'main_category': 'Photography',
#   'currency': 'GBP',
#   'deadline': '2014-11-05',
#   'goal': 200.0,
#   'launched': '2014-09-06 01:24:05',
#   'pledged': 4.0,
#   'state': 'failed',
#   'backers': 2.0,
#   'country': 'GB',
#   'usd_pledged': 6.58338684,
#   'usd_pledged_real': 6.327812317086678},
#  {'ID': 1434110341,
#   'name': 'The Prettiest Panties in the World (Canceled)',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-01-11',
#   'goal': 30000.0,
#   'launched': '2015-12-01 18:00:24',
#   'pledged': 427.0,
#   'state': 'canceled',
#   'backers': 9.0,
#   'country': 'US',
#   'usd_pledged': 427.0,
#   'usd_pledged_real': 427.0},
#  {'ID': 48806525,
#   'name': 'Coffee Crisis for the Sega Genesis - Metal, Aliens & Awesome',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-12-04',
#   'goal': 10000.0,
#   'launched': '2016-11-04 21:22:22',
#   'pledged': 15076.0,
#   'state': 'successful',
#   'backers': 213.0,
#   'country': 'US',
#   'usd_pledged': 1917.0,
#   'usd_pledged_real': 15076.0},
#  {'ID': 1439048120,
#   'name': 'The Black Operator',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-07-12',
#   'goal': 3300.0,
#   'launched': '2013-06-12 03:05:30',
#   'pledged': 1134.0,
#   'state': 'failed',
#   'backers': 32.0,
#   'country': 'US',
#   'usd_pledged': 1134.0,
#   'usd_pledged_real': 1134.0},
#  {'ID': 1300265365,
#   'name': 'The Athlete Spot: We Have The Ingredients For Your Success',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2018-01-09',
#   'goal': 50000.0,
#   'launched': '2017-11-10 03:59:11',
#   'pledged': 0.0,
#   'state': 'live',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 513123115,
#   'name': "Kaila Gieser's debut EP!",
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-05-10',
#   'goal': 1500.0,
#   'launched': '2013-04-08 19:15:48',
#   'pledged': 25.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 25.0,
#   'usd_pledged_real': 25.0},
#  {'ID': 1506474844,
#   'name': "The Revolution's Bride",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-07-02',
#   'goal': 15000.0,
#   'launched': '2016-06-04 19:59:25',
#   'pledged': 10.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 10.0,
#   'usd_pledged_real': 10.0},
#  {'ID': 1252795414,
#   'name': 'EZC Smartlight "The Smarter Way To Ride"',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2016-04-12',
#   'goal': 400.0,
#   'launched': '2016-03-08 13:26:58',
#   'pledged': 1595.0,
#   'state': 'successful',
#   'backers': 22.0,
#   'country': 'CA',
#   'usd_pledged': 1195.5930195,
#   'usd_pledged_real': 1238.2578992314259},
#  {'ID': 1721170633,
#   'name': 'LINJA shoes - The Finest Comfortable High Heels',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-09-22',
#   'goal': 25000.0,
#   'launched': '2016-09-06 12:32:38',
#   'pledged': 19410.0,
#   'state': 'failed',
#   'backers': 112.0,
#   'country': 'NL',
#   'usd_pledged': 4733.727817600001,
#   'usd_pledged_real': 21766.434162424022},
#  {'ID': 666068495,
#   'name': '360ï¿½ India',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'GBP',
#   'deadline': '2015-08-01',
#   'goal': 700.0,
#   'launched': '2015-07-22 11:40:00',
#   'pledged': 16.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'GB',
#   'usd_pledged': 24.9036152,
#   'usd_pledged_real': 24.826986934798125},
#  {'ID': 1884096172,
#   'name': 'The Wing Commander Orchestral Project Volume 2, Phase 1!',
#   'category': 'Jazz',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2017-08-26',
#   'goal': 15000.0,
#   'launched': '2017-07-27 21:58:33',
#   'pledged': 16552.0,
#   'state': 'successful',
#   'backers': 275.0,
#   'country': 'US',
#   'usd_pledged': 5130.0,
#   'usd_pledged_real': 16552.0},
#  {'ID': 358516752,
#   'name': 'My YouTube Band Project',
#   'category': 'Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2012-07-10',
#   'goal': 35000.0,
#   'launched': '2012-06-09 23:58:18',
#   'pledged': 79937.33,
#   'state': 'successful',
#   'backers': 680.0,
#   'country': 'US',
#   'usd_pledged': 79937.33,
#   'usd_pledged_real': 79937.33},
#  {'ID': 1658564725,
#   'name': 'Help Fund a \'Miraculous\'  new Musical, "Miracolo"',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2013-10-24',
#   'goal': 18000.0,
#   'launched': '2013-09-14 17:41:56',
#   'pledged': 18000.0,
#   'state': 'successful',
#   'backers': 51.0,
#   'country': 'US',
#   'usd_pledged': 18000.0,
#   'usd_pledged_real': 18000.0},
#  {'ID': 2071301174,
#   'name': 'Wallets Refined & Redefined - by Obtainium',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-01-07',
#   'goal': 25000.0,
#   'launched': '2012-11-23 14:59:13',
#   'pledged': 88867.0,
#   'state': 'successful',
#   'backers': 715.0,
#   'country': 'US',
#   'usd_pledged': 88867.0,
#   'usd_pledged_real': 88867.0},
#  {'ID': 2055734097,
#   'name': 'Powermitten: EPIC performance and Album Mastering (Canceled)',
#   'category': 'Electronic Music',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2011-05-04',
#   'goal': 1100.0,
#   'launched': '2011-04-22 08:39:10',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 252240271,
#   'name': 'Best Man Competition Webseries',
#   'category': 'Webseries',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-03',
#   'goal': 9500.0,
#   'launched': '2013-07-03 20:35:13',
#   'pledged': 377.0,
#   'state': 'failed',
#   'backers': 8.0,
#   'country': 'US',
#   'usd_pledged': 377.0,
#   'usd_pledged_real': 377.0},
#  {'ID': 12976470,
#   'name': 'Love Collection',
#   'category': 'Painting',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2013-02-28',
#   'goal': 5000.0,
#   'launched': '2013-01-29 04:45:19',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 581166953,
#   'name': 'Pay my rent, dance a jig!',
#   'category': 'Dance',
#   'main_category': 'Dance',
#   'currency': 'AUD',
#   'deadline': '2014-08-09',
#   'goal': 3000.0,
#   'launched': '2014-07-10 01:19:48',
#   'pledged': 1.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'AU',
#   'usd_pledged': 0.93876087,
#   'usd_pledged_real': 0.9321401938851605},
#  {'ID': 1780435209,
#   'name': 'The Holophonics Record a New Ska Cover Album',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-09-28',
#   'goal': 2000.0,
#   'launched': '2013-08-29 19:07:17',
#   'pledged': 2899.5,
#   'state': 'successful',
#   'backers': 51.0,
#   'country': 'US',
#   'usd_pledged': 2899.5,
#   'usd_pledged_real': 2899.5},
#  {'ID': 2057158348,
#   'name': 'BubblePhoneCaseï¿½, Top anti-hacking phone case system.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-12-06',
#   'goal': 10000.0,
#   'launched': '2016-10-31 15:19:14',
#   'pledged': 349.0,
#   'state': 'canceled',
#   'backers': 1.0,
#   'country': 'ES',
#   'usd_pledged': 383.49541128,
#   'usd_pledged_real': 368.5088589952062},
#  {'ID': 93529012,
#   'name': 'Hamtramck Labor Day Festival',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2012-07-19',
#   'goal': 20000.0,
#   'launched': '2012-06-19 18:04:53',
#   'pledged': 2366.0,
#   'state': 'failed',
#   'backers': 44.0,
#   'country': 'US',
#   'usd_pledged': 2366.0,
#   'usd_pledged_real': 2366.0},
#  {'ID': 1551300378,
#   'name': 'Crab Cakes',
#   'category': 'Shorts',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-01-01',
#   'goal': 3000.0,
#   'launched': '2012-11-02 18:46:42',
#   'pledged': 775.0,
#   'state': 'failed',
#   'backers': 7.0,
#   'country': 'US',
#   'usd_pledged': 775.0,
#   'usd_pledged_real': 775.0},
#  {'ID': 819881112,
#   'name': 'Excellent "Made in Italy" leather shoes for man/woman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2016-12-18',
#   'goal': 178250.0,
#   'launched': '2016-11-16 18:18:47',
#   'pledged': 765.0,
#   'state': 'failed',
#   'backers': 19.0,
#   'country': 'IT',
#   'usd_pledged': 344.0120416000001,
#   'usd_pledged_real': 799.1225321215919},
#  {'ID': 1776712156,
#   'name': 'Twig the Fairy and the Fairly Short Fairy Tales',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-12-13',
#   'goal': 17000.0,
#   'launched': '2015-11-21 02:06:15',
#   'pledged': 25410.0,
#   'state': 'successful',
#   'backers': 315.0,
#   'country': 'US',
#   'usd_pledged': 25410.0,
#   'usd_pledged_real': 25410.0},
#  {'ID': 255401982,
#   'name': 'Civil Architect',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2014-12-20',
#   'goal': 100000.0,
#   'launched': '2014-11-20 22:00:13',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'GB',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 750725377,
#   'name': 'GHETTO CHRONICLES The Musical Comedy Stage Play (Canceled)',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'USD',
#   'deadline': '2011-09-04',
#   'goal': 10000.0,
#   'launched': '2011-07-21 08:13:42',
#   'pledged': 0.0,
#   'state': 'canceled',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 147428325,
#   'name': 'Flyy Magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2012-02-17',
#   'goal': 10000.0,
#   'launched': '2012-01-18 03:55:27',
#   'pledged': 20.0,
#   'state': 'failed',
#   'backers': 1.0,
#   'country': 'US',
#   'usd_pledged': 20.0,
#   'usd_pledged_real': 20.0},
#  {'ID': 400288569,
#   'name': 'Dracucat : A vampire kitten card game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'EUR',
#   'deadline': '2015-10-29',
#   'goal': 1900.0,
#   'launched': '2015-09-29 07:04:08',
#   'pledged': 2944.0,
#   'state': 'successful',
#   'backers': 129.0,
#   'country': 'FR',
#   'usd_pledged': 3295.37237632,
#   'usd_pledged_real': 3243.3980764357875},
#  {'ID': 1050943303,
#   'name': "Little Baby's Ice Cream Funds for Responsible Packaging",
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-07-10',
#   'goal': 5952.0,
#   'launched': '2012-06-15 06:03:09',
#   'pledged': 6314.0,
#   'state': 'successful',
#   'backers': 151.0,
#   'country': 'US',
#   'usd_pledged': 6314.0,
#   'usd_pledged_real': 6314.0},
#  {'ID': 1774424016,
#   'name': 'Leadseed',
#   'category': 'Web',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-19',
#   'goal': 2500.0,
#   'launched': '2014-06-20 19:31:58',
#   'pledged': 0.0,
#   'state': 'failed',
#   'backers': 0.0,
#   'country': 'US',
#   'usd_pledged': 0.0,
#   'usd_pledged_real': 0.0},
#  {'ID': 410739785,
#   'name': "Kid's Fruit & Veggie Garden Certificate (Canceled)",
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2012-08-30',
#   'goal': 10000.0,
#   'launched': '2012-07-31 01:52:47',
#   'pledged': 75.0,
#   'state': 'canceled',
#   'backers': 3.0,
#   'country': 'US',
#   'usd_pledged': 75.0,
#   'usd_pledged_real': 75.0},
#  {'ID': 205452254,
#   'name': 'Independent Metal/Punk Band - New Recording',
#   'category': 'Metal',
#   'main_category': 'Music',
#   'currency': 'CAD',
#   'deadline': '2014-04-23',
#   'goal': 800.0,
#   'launched': '2014-03-14 19:24:44',
#   'pledged': 960.0,
#   'state': 'successful',
#   'backers': 27.0,
#   'country': 'CA',
#   'usd_pledged': 864.5984735999997,
#   'usd_pledged_real': 871.3015066255217},
#  {'ID': 128564589,
#   'name': 'The Canada Grill Barbecue',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2013-10-27',
#   'goal': 25000.0,
#   'launched': '2013-09-12 18:50:23',
#   'pledged': 112.0,
#   'state': 'failed',
#   'backers': 4.0,
#   'country': 'CA',
#   'usd_pledged': 108.2184152,
#   'usd_pledged_real': 107.41344586170521},
#  {'ID': 913821004,
#   'name': '"Zero Day" Minimalist Survival Kit ZDSK',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-16',
#   'goal': 15000.0,
#   'launched': '2015-09-02 00:27:57',
#   'pledged': 15140.0,
#   'state': 'successful',
#   'backers': 120.0,
#   'country': 'US',
#   'usd_pledged': 15140.0,
#   'usd_pledged_real': 15140.0},
#  ...]

# %%
collection_ks.drop()

# %%
collection_ks.insert_many(df_ks_dict)

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'exercices', 'local']

# %% [markdown]
# ## Question 1

# %%
cur_ex1 = collection_ks.find().sort([("pledged", -1)]).limit(5)

# %%
list(cur_ex1)
# Out:
# [{'_id': ObjectId('601d0a42941a132c4d2557cd'),
#   'ID': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-08-30',
#   'goal': 50000.0,
#   'launched': '2014-07-08 10:14:37',
#   'pledged': 13285226.36,
#   'state': 'successful',
#   'backers': 62642.0,
#   'country': 'US',
#   'usd_pledged': 13285226.36,
#   'usd_pledged_real': 13285226.36},
#  {'_id': ObjectId('601d0a42941a132c4d25b19c'),
#   'ID': 2103598555,
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-06-30',
#   'goal': 1000000.0,
#   'launched': '2016-05-24 15:49:52',
#   'pledged': 12779843.49,
#   'state': 'successful',
#   'backers': 66673.0,
#   'country': 'US',
#   'usd_pledged': 12779843.49,
#   'usd_pledged_real': 12779843.49},
#  {'_id': ObjectId('601d0a42941a132c4d2563da'),
#   'ID': 2111201788,
#   'name': 'Expect the Unexpected. digiFilmï¿½ Camera by YASHICA',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-11-19',
#   'goal': 800000.0,
#   'launched': '2017-10-10 12:52:25',
#   'pledged': 10035296.0,
#   'state': 'successful',
#   'backers': 6935.0,
#   'country': 'HK',
#   'usd_pledged': 4788.64216028,
#   'usd_pledged_real': 1285142.981546224},
#  {'_id': ObjectId('601d0a43941a132c4d25e5f1'),
#   'ID': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-08-09',
#   'goal': 950000.0,
#   'launched': '2012-07-10 14:44:41',
#   'pledged': 8596474.58,
#   'state': 'successful',
#   'backers': 63416.0,
#   'country': 'US',
#   'usd_pledged': 8596474.58,
#   'usd_pledged_real': 8596474.58},
#  {'_id': ObjectId('601d0a43941a132c4d265bc6'),
#   'ID': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': '2016-07-13 00:47:35',
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359.0,
#   'country': 'US',
#   'usd_pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5}]

# %% [markdown]
# ## Question 2

# %%
collection_ks.count_documents({"state" : "successful"})
# Out:
# 52832

# %% [markdown]
# ## Question 3

# %%
cur_ex3 = collection_ks.aggregate([{'$group' : {'_id': '$category', 'countByCategory' : {'$sum' : 1}}}])

# %%
list(cur_ex3)
# Out:
# [{'_id': 'Civic Design', 'countByCategory': 130},
#  {'_id': 'Weaving', 'countByCategory': 38},
#  {'_id': 'Games', 'countByCategory': 1322},
#  {'_id': 'Embroidery', 'countByCategory': 49},
#  {'_id': 'Metal', 'countByCategory': 273},
#  {'_id': 'Latin', 'countByCategory': 61},
#  {'_id': 'Video', 'countByCategory': 145},
#  {'_id': 'Community Gardens', 'countByCategory': 114},
#  {'_id': 'Conceptual Art', 'countByCategory': 392},
#  {'_id': 'Wearables', 'countByCategory': 508},
#  {'_id': 'Indie Rock', 'countByCategory': 2187},
#  {'_id': 'Drama', 'countByCategory': 861},
#  {'_id': 'Nonfiction', 'countByCategory': 3385},
#  {'_id': 'Publishing', 'countByCategory': 2141},
#  {'_id': 'Rock', 'countByCategory': 2700},
#  {'_id': 'Country & Folk', 'countByCategory': 1787},
#  {'_id': 'Science Fiction', 'countByCategory': 269},
#  {'_id': 'Accessories', 'countByCategory': 1200},
#  {'_id': 'Textiles', 'countByCategory': 105},
#  {'_id': 'Playing Cards', 'countByCategory': 960},
#  {'_id': 'Tabletop Games', 'countByCategory': 5558},
#  {'_id': 'Vegan', 'countByCategory': 228},
#  {'_id': 'Musical', 'countByCategory': 364},
#  {'_id': 'Food', 'countByCategory': 4595},
#  {'_id': 'Places', 'countByCategory': 282},
#  {'_id': 'Classical Music', 'countByCategory': 1061},
#  {'_id': 'Music Videos', 'countByCategory': 297},
#  {'_id': 'Fashion', 'countByCategory': 3377},
#  {'_id': 'Knitting', 'countByCategory': 78},
#  {'_id': 'Zines', 'countByCategory': 144},
#  {'_id': 'Bacon', 'countByCategory': 75},
#  {'_id': 'Webseries', 'countByCategory': 2310},
#  {'_id': 'Punk', 'countByCategory': 127},
#  {'_id': 'Footwear', 'countByCategory': 379},
#  {'_id': 'Typography', 'countByCategory': 44},
#  {'_id': 'Radio & Podcasts', 'countByCategory': 349},
#  {'_id': 'Cookbooks', 'countByCategory': 217},
#  {'_id': 'Painting', 'countByCategory': 1286},
#  {'_id': 'Hip-Hop', 'countByCategory': 1551},
#  {'_id': 'Photography', 'countByCategory': 2230},
#  {'_id': 'Animation', 'countByCategory': 1011},
#  {'_id': 'Sound', 'countByCategory': 254},
#  {'_id': 'Young Adult', 'countByCategory': 327},
#  {'_id': 'Faith', 'countByCategory': 434},
#  {'_id': 'Horror', 'countByCategory': 521},
#  {'_id': 'Technology', 'countByCategory': 2683},
#  {'_id': 'Glass', 'countByCategory': 51},
#  {'_id': 'Gaming Hardware', 'countByCategory': 178},
#  {'_id': 'Video Art', 'countByCategory': 65},
#  {'_id': 'Spaces', 'countByCategory': 331},
#  {'_id': 'Graphic Design', 'countByCategory': 764},
#  {'_id': 'Jazz', 'countByCategory': 729},
#  {'_id': 'Performances', 'countByCategory': 413},
#  {'_id': 'Photobooks', 'countByCategory': 607},
#  {'_id': 'Apparel', 'countByCategory': 2824},
#  {'_id': 'R&B', 'countByCategory': 171},
#  {'_id': 'Restaurants', 'countByCategory': 1088},
#  {'_id': 'Gadgets', 'countByCategory': 1208},
#  {'_id': 'Film & Video', 'countByCategory': 3634},
#  {'_id': 'Photo', 'countByCategory': 58},
#  {'_id': 'Comic Books', 'countByCategory': 1029},
#  {'_id': 'Family', 'countByCategory': 129},
#  {'_id': 'Anthologies', 'countByCategory': 299},
#  {'_id': "Farmer's Markets", 'countByCategory': 175},
#  {'_id': 'Space Exploration', 'countByCategory': 136},
#  {'_id': 'Architecture', 'countByCategory': 300},
#  {'_id': 'Food Trucks', 'countByCategory': 687},
#  {'_id': 'DIY', 'countByCategory': 478},
#  {'_id': 'Shorts', 'countByCategory': 4801},
#  {'_id': 'Television', 'countByCategory': 399},
#  {'_id': 'Nature', 'countByCategory': 219},
#  {'_id': 'Immersive', 'countByCategory': 130},
#  {'_id': 'Print', 'countByCategory': 286},
#  {'_id': 'Academic', 'countByCategory': 366},
#  {'_id': 'Webcomics', 'countByCategory': 259},
#  {'_id': '3D Printing', 'countByCategory': 271},
#  {'_id': 'Comics', 'countByCategory': 1927},
#  {'_id': 'Mobile Games', 'countByCategory': 647},
#  {'_id': 'Chiptune', 'countByCategory': 10},
#  {'_id': 'Performance Art', 'countByCategory': 854},
#  {'_id': 'Graphic Novels', 'countByCategory': 700},
#  {'_id': 'Printing', 'countByCategory': 83},
#  {'_id': 'Festivals', 'countByCategory': 311},
#  {'_id': 'Audio', 'countByCategory': 164},
#  {'_id': 'Literary Journals', 'countByCategory': 118},
#  {'_id': 'Romance', 'countByCategory': 74},
#  {'_id': 'Jewelry', 'countByCategory': 471},
#  {'_id': 'Flight', 'countByCategory': 158},
#  {'_id': 'Pop', 'countByCategory': 1297},
#  {'_id': 'Live Games', 'countByCategory': 394},
#  {'_id': 'Periodicals', 'countByCategory': 517},
#  {'_id': 'Action', 'countByCategory': 279},
#  {'_id': 'Movie Theaters', 'countByCategory': 90},
#  {'_id': 'Public Art', 'countByCategory': 1245},
#  {'_id': 'Candles', 'countByCategory': 167},
#  {'_id': 'Crafts', 'countByCategory': 1829},
#  {'_id': 'Pottery', 'countByCategory': 40},
#  {'_id': 'Video Games', 'countByCategory': 4768},
#  {'_id': 'Makerspaces', 'countByCategory': 91},
#  {'_id': 'Pet Fashion', 'countByCategory': 51},
#  {'_id': 'Hardware', 'countByCategory': 1430},
#  {'_id': 'Music', 'countByCategory': 5279},
#  {'_id': 'Design', 'countByCategory': 1640},
#  {'_id': 'Comedy', 'countByCategory': 919},
#  {'_id': 'Fiction', 'countByCategory': 3687},
#  {'_id': 'Residencies', 'countByCategory': 32},
#  {'_id': 'Robots', 'countByCategory': 237},
#  {'_id': 'Blues', 'countByCategory': 113},
#  {'_id': 'Electronic Music', 'countByCategory': 854},
#  {'_id': 'Woodworking', 'countByCategory': 431},
#  {'_id': 'Animals', 'countByCategory': 97},
#  {'_id': 'Fantasy', 'countByCategory': 132},
#  {'_id': 'People', 'countByCategory': 440},
#  {'_id': 'Crochet', 'countByCategory': 61},
#  {'_id': 'Camera Equipment', 'countByCategory': 165},
#  {'_id': 'Product Design', 'countByCategory': 8864},
#  {'_id': 'Digital Art', 'countByCategory': 524},
#  {'_id': 'Farms', 'countByCategory': 482},
#  {'_id': 'Software', 'countByCategory': 1192},
#  {'_id': 'Events', 'countByCategory': 320},
#  {'_id': 'Web', 'countByCategory': 2015},
#  {'_id': 'Documentary', 'countByCategory': 6481},
#  {'_id': 'Illustration', 'countByCategory': 1261},
#  {'_id': 'Narrative Film', 'countByCategory': 2081},
#  {'_id': 'Childrenswear', 'countByCategory': 192},
#  {'_id': 'Art Books', 'countByCategory': 1063},
#  {'_id': 'Art', 'countByCategory': 3343},
#  {'_id': 'Taxidermy', 'countByCategory': 7},
#  {'_id': 'Ready-to-wear', 'countByCategory': 332},
#  {'_id': 'Experimental', 'countByCategory': 354},
#  {'_id': 'Translations', 'countByCategory': 76},
#  {'_id': 'Letterpress', 'countByCategory': 24},
#  {'_id': 'Plays', 'countByCategory': 537},
#  {'_id': 'Mixed Media', 'countByCategory': 1116},
#  {'_id': 'Ceramics', 'countByCategory': 126},
#  {'_id': 'Theater', 'countByCategory': 2773},
#  {'_id': 'Workshops', 'countByCategory': 59},
#  {'_id': 'Installations', 'countByCategory': 178},
#  {'_id': 'Couture', 'countByCategory': 108},
#  {'_id': 'Quilts', 'countByCategory': 32},
#  {'_id': 'Small Batch', 'countByCategory': 697},
#  {'_id': 'Apps', 'countByCategory': 2528},
#  {'_id': 'Puzzles', 'countByCategory': 95},
#  {'_id': 'Kids', 'countByCategory': 109},
#  {'_id': 'Calendars', 'countByCategory': 111},
#  {'_id': 'Interactive Design', 'countByCategory': 146},
#  {'_id': 'Journalism', 'countByCategory': 671},
#  {'_id': 'Poetry', 'countByCategory': 531},
#  {'_id': 'DIY Electronics', 'countByCategory': 358},
#  {'_id': "Children's Books", 'countByCategory': 2678},
#  {'_id': 'Fine Art', 'countByCategory': 290},
#  {'_id': 'Literary Spaces', 'countByCategory': 10},
#  {'_id': 'World Music', 'countByCategory': 847},
#  {'_id': 'Sculpture', 'countByCategory': 733},
#  {'_id': 'Stationery', 'countByCategory': 90},
#  {'_id': 'Dance', 'countByCategory': 899},
#  {'_id': 'Thrillers', 'countByCategory': 299},
#  {'_id': 'Fabrication Tools', 'countByCategory': 95},
#  {'_id': 'Drinks', 'countByCategory': 992}]

# %%
cur_ex3 = collection_ks.aggregate([{'$group' : {'_id': '$main_category', 'count_By_main_Category' : {'$sum' : 1}}}])

# %%
list(cur_ex3)
# Out:
# [{'_id': 'Film & Video', 'count_By_main_Category': 24821},
#  {'_id': 'Dance', 'count_By_main_Category': 1486},
#  {'_id': 'Photography', 'count_By_main_Category': 4165},
#  {'_id': 'Theater', 'count_By_main_Category': 4285},
#  {'_id': 'Journalism', 'count_By_main_Category': 1803},
#  {'_id': 'Art', 'count_By_main_Category': 11228},
#  {'_id': 'Fashion', 'count_By_main_Category': 8934},
#  {'_id': 'Publishing', 'count_By_main_Category': 15679},
#  {'_id': 'Music', 'count_By_main_Category': 19596},
#  {'_id': 'Design', 'count_By_main_Category': 11888},
#  {'_id': 'Food', 'count_By_main_Category': 9775},
#  {'_id': 'Technology', 'count_By_main_Category': 12850},
#  {'_id': 'Crafts', 'count_By_main_Category': 3453},
#  {'_id': 'Games', 'count_By_main_Category': 13922},
#  {'_id': 'Comics', 'count_By_main_Category': 4130}]

# %% [markdown]
# ## Question 4

# %%
collection_ks.count_documents({"$and" : [{"country":'FR'}, {"launched":{'$lt' : '2016-01-01'}}]})
# Out:
# 329

# %% [markdown]
# ## Question 5

# %%
cur_ex5 = collection_ks.find({"$and" : [{"country":'US'}, {"usd_pledged":{'$gte' : 200000}}]})

# %%
list(cur_ex5)
# Out:
# [{'_id': ObjectId('601d0a42941a132c4d24306a'),
#   'ID': 217543389,
#   'name': 'The uKeg Pressurized Growler for Fresh Beer',
#   'category': 'Drinks',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-12-08',
#   'goal': 75000.0,
#   'launched': '2014-10-15 06:34:48',
#   'pledged': 1559525.68,
#   'state': 'successful',
#   'backers': 10293.0,
#   'country': 'US',
#   'usd_pledged': 1559525.68,
#   'usd_pledged_real': 1559525.68},
#  {'_id': ObjectId('601d0a42941a132c4d2430f9'),
#   'ID': 909248984,
#   'name': 'Redux COURG - Hybrid Watches with Missions to Tackle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-20',
#   'goal': 30000.0,
#   'launched': '2015-07-21 19:01:41',
#   'pledged': 692912.0,
#   'state': 'successful',
#   'backers': 2200.0,
#   'country': 'US',
#   'usd_pledged': 692912.0,
#   'usd_pledged_real': 692912.0},
#  {'_id': ObjectId('601d0a42941a132c4d2431a6'),
#   'ID': 1688905333,
#   'name': 'Legion Solar - A Better Way to Energy Independence',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-18',
#   'goal': 50000.0,
#   'launched': '2016-05-03 16:00:22',
#   'pledged': 277524.0,
#   'state': 'successful',
#   'backers': 399.0,
#   'country': 'US',
#   'usd_pledged': 277524.0,
#   'usd_pledged_real': 277524.0},
#  {'_id': ObjectId('601d0a42941a132c4d2432c3'),
#   'ID': 447408232,
#   'name': 'Edyn: Welcome to the connected garden.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-08',
#   'goal': 100000.0,
#   'launched': '2014-06-05 13:50:13',
#   'pledged': 384201.63,
#   'state': 'successful',
#   'backers': 2336.0,
#   'country': 'US',
#   'usd_pledged': 384201.63,
#   'usd_pledged_real': 384201.63},
#  {'_id': ObjectId('601d0a42941a132c4d2432d2'),
#   'ID': 1919184836,
#   'name': 'Period Panties',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2014-03-09',
#   'goal': 10000.0,
#   'launched': '2014-02-07 15:32:50',
#   'pledged': 404763.3,
#   'state': 'successful',
#   'backers': 9550.0,
#   'country': 'US',
#   'usd_pledged': 404763.3,
#   'usd_pledged_real': 404763.3},
#  {'_id': ObjectId('601d0a42941a132c4d2433b9'),
#   'ID': 828587276,
#   'name': 'Shadowrun: Hong Kong',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-17',
#   'goal': 100000.0,
#   'launched': '2015-01-13 18:45:24',
#   'pledged': 1204726.47,
#   'state': 'successful',
#   'backers': 31497.0,
#   'country': 'US',
#   'usd_pledged': 1204726.47,
#   'usd_pledged_real': 1204726.47},
#  {'_id': ObjectId('601d0a42941a132c4d24342f'),
#   'ID': 821637012,
#   'name': 'Kurt Vonnegut: Unstuck in Time',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-10',
#   'goal': 250000.0,
#   'launched': '2015-02-10 14:05:34',
#   'pledged': 300319.0,
#   'state': 'successful',
#   'backers': 3755.0,
#   'country': 'US',
#   'usd_pledged': 300319.0,
#   'usd_pledged_real': 300319.0},
#  {'_id': ObjectId('601d0a42941a132c4d243484'),
#   'ID': 1075169964,
#   'name': 'Battle Worlds: Kronos - Turn-based strategy revisited',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-04-28',
#   'goal': 120000.0,
#   'launched': '2013-03-19 10:44:15',
#   'pledged': 260235.9,
#   'state': 'successful',
#   'backers': 7564.0,
#   'country': 'US',
#   'usd_pledged': 260235.9,
#   'usd_pledged_real': 260235.9},
#  {'_id': ObjectId('601d0a42941a132c4d243517'),
#   'ID': 1339618489,
#   'name': 'Hie Diaper Bag: Your New Best Friend',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-07-15',
#   'goal': 60000.0,
#   'launched': '2017-06-12 17:54:56',
#   'pledged': 395666.0,
#   'state': 'successful',
#   'backers': 1882.0,
#   'country': 'US',
#   'usd_pledged': 259582.0,
#   'usd_pledged_real': 395666.0},
#  {'_id': ObjectId('601d0a42941a132c4d243570'),
#   'ID': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': '2014-12-10 18:58:08',
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096.0,
#   'country': 'US',
#   'usd_pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('601d0a42941a132c4d2435f2'),
#   'ID': 956638568,
#   'name': 'Dobot: Robotic Arm for Everyone, Arduino & Open Source',
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-11-04',
#   'goal': 36000.0,
#   'launched': '2015-09-15 14:53:19',
#   'pledged': 615600.0,
#   'state': 'successful',
#   'backers': 1208.0,
#   'country': 'US',
#   'usd_pledged': 615600.0,
#   'usd_pledged_real': 615600.0},
#  {'_id': ObjectId('601d0a42941a132c4d2438b4'),
#   'ID': 1299968108,
#   'name': 'PolySmooth & Polysher: 3D Prints Without Layers',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-05-25',
#   'goal': 100000.0,
#   'launched': '2016-04-25 17:59:57',
#   'pledged': 433860.0,
#   'state': 'successful',
#   'backers': 1343.0,
#   'country': 'US',
#   'usd_pledged': 433860.0,
#   'usd_pledged_real': 433860.0},
#  {'_id': ObjectId('601d0a42941a132c4d2439d0'),
#   'ID': 726969634,
#   'name': 'Sails of Glory - Miniatures Ship Combat',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-04-16',
#   'goal': 30000.0,
#   'launched': '2013-03-05 08:54:47',
#   'pledged': 276745.0,
#   'state': 'successful',
#   'backers': 1183.0,
#   'country': 'US',
#   'usd_pledged': 276745.0,
#   'usd_pledged_real': 276745.0},
#  {'_id': ObjectId('601d0a42941a132c4d243a77'),
#   'ID': 1587924529,
#   'name': 'The Temperfect Mug: Coffee and Tea at The Perfect Temp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-01-01',
#   'goal': 23500.0,
#   'launched': '2013-11-24 23:26:14',
#   'pledged': 269271.01,
#   'state': 'successful',
#   'backers': 4903.0,
#   'country': 'US',
#   'usd_pledged': 269271.01,
#   'usd_pledged_real': 269271.01},
#  {'_id': ObjectId('601d0a42941a132c4d2441b6'),
#   'ID': 1957695328,
#   'name': 'Planetary Annihilation - A Next Generation RTS',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-09-14',
#   'goal': 900000.0,
#   'launched': '2012-08-15 21:20:10',
#   'pledged': 2229344.36,
#   'state': 'successful',
#   'backers': 44162.0,
#   'country': 'US',
#   'usd_pledged': 2229344.36,
#   'usd_pledged_real': 2229344.36},
#  {'_id': ObjectId('601d0a42941a132c4d24421d'),
#   'ID': 1572015807,
#   'name': "Aeon's End: War Eternal",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-21',
#   'goal': 30000.0,
#   'launched': '2017-03-21 16:15:57',
#   'pledged': 434703.0,
#   'state': 'successful',
#   'backers': 3890.0,
#   'country': 'US',
#   'usd_pledged': 201364.0,
#   'usd_pledged_real': 434703.0},
#  {'_id': ObjectId('601d0a42941a132c4d244258'),
#   'ID': 1497942355,
#   'name': 'XERISCOPE: The Orbiting Mechanical Automatic Watch by XERIC',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-12-21',
#   'goal': 40000.0,
#   'launched': '2013-11-06 15:21:46',
#   'pledged': 444370.38,
#   'state': 'successful',
#   'backers': 1148.0,
#   'country': 'US',
#   'usd_pledged': 444370.38,
#   'usd_pledged_real': 444370.38},
#  {'_id': ObjectId('601d0a42941a132c4d24430e'),
#   'ID': 1709793760,
#   'name': 'Canary in a Coal Mine',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-11-23',
#   'goal': 50000.0,
#   'launched': '2013-10-22 18:44:25',
#   'pledged': 212962.22,
#   'state': 'successful',
#   'backers': 2593.0,
#   'country': 'US',
#   'usd_pledged': 212962.22,
#   'usd_pledged_real': 212962.22},
#  {'_id': ObjectId('601d0a42941a132c4d24448e'),
#   'ID': 851609835,
#   'name': 'Akaneiro: Demon Hunters',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-02-03',
#   'goal': 200000.0,
#   'launched': '2013-01-04 00:27:43',
#   'pledged': 204680.93,
#   'state': 'successful',
#   'backers': 2681.0,
#   'country': 'US',
#   'usd_pledged': 204680.93,
#   'usd_pledged_real': 204680.93},
#  {'_id': ObjectId('601d0a42941a132c4d244591'),
#   'ID': 271631066,
#   'name': 'MYTH: Journeyman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-29',
#   'goal': 80000.0,
#   'launched': '2015-03-09 16:58:49',
#   'pledged': 972886.0,
#   'state': 'successful',
#   'backers': 4739.0,
#   'country': 'US',
#   'usd_pledged': 972886.0,
#   'usd_pledged_real': 972886.0},
#  {'_id': ObjectId('601d0a42941a132c4d2445a6'),
#   'ID': 874722536,
#   'name': 'The ultimate sleep sanctuary: Kokoon EEG headphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-10',
#   'goal': 100000.0,
#   'launched': '2015-05-11 17:00:32',
#   'pledged': 1936825.0,
#   'state': 'successful',
#   'backers': 8489.0,
#   'country': 'US',
#   'usd_pledged': 1936825.0,
#   'usd_pledged_real': 1936825.0},
#  {'_id': ObjectId('601d0a42941a132c4d2446ad'),
#   'ID': 644614031,
#   'name': "Iota: Never lose sight of what's important.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-14',
#   'goal': 250000.0,
#   'launched': '2014-07-15 08:19:05',
#   'pledged': 282155.0,
#   'state': 'successful',
#   'backers': 1657.0,
#   'country': 'US',
#   'usd_pledged': 282155.0,
#   'usd_pledged_real': 282155.0},
#  {'_id': ObjectId('601d0a42941a132c4d2446ba'),
#   'ID': 121842661,
#   'name': 'Pixy (CMUcam5): a fast, easy-to-use vision sensor',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-09-14',
#   'goal': 25000.0,
#   'launched': '2013-08-15 08:15:31',
#   'pledged': 274352.11,
#   'state': 'successful',
#   'backers': 2802.0,
#   'country': 'US',
#   'usd_pledged': 274352.11,
#   'usd_pledged_real': 274352.11},
#  {'_id': ObjectId('601d0a42941a132c4d244c44'),
#   'ID': 1349593857,
#   'name': 'Reissue of the 1975 NASA Graphics Standards Manual.',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-05',
#   'goal': 158000.0,
#   'launched': '2015-09-01 05:56:35',
#   'pledged': 941966.92,
#   'state': 'successful',
#   'backers': 8798.0,
#   'country': 'US',
#   'usd_pledged': 941966.92,
#   'usd_pledged_real': 941966.92},
#  {'_id': ObjectId('601d0a42941a132c4d244cde'),
#   'ID': 1834526569,
#   'name': 'Unsung Story: Tale of the Guardians',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-15',
#   'goal': 600000.0,
#   'launched': '2014-01-14 19:03:30',
#   'pledged': 660126.51,
#   'state': 'successful',
#   'backers': 15824.0,
#   'country': 'US',
#   'usd_pledged': 660126.51,
#   'usd_pledged_real': 660126.51},
#  {'_id': ObjectId('601d0a42941a132c4d245035'),
#   'ID': 1067930555,
#   'name': 'Radian 2: Time Lapse, Motion, and Wireless Camera Control',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-05',
#   'goal': 153471.0,
#   'launched': '2015-05-07 18:58:56',
#   'pledged': 272238.0,
#   'state': 'successful',
#   'backers': 916.0,
#   'country': 'US',
#   'usd_pledged': 272238.0,
#   'usd_pledged_real': 272238.0},
#  {'_id': ObjectId('601d0a42941a132c4d245195'),
#   'ID': 350259914,
#   'name': "Notion: Be home, even when you're not.",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-10-16',
#   'goal': 50000.0,
#   'launched': '2014-09-16 17:54:46',
#   'pledged': 281655.51,
#   'state': 'successful',
#   'backers': 1338.0,
#   'country': 'US',
#   'usd_pledged': 281655.51,
#   'usd_pledged_real': 281655.51},
#  {'_id': ObjectId('601d0a42941a132c4d24521c'),
#   'ID': 749406436,
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-22',
#   'goal': 500000.0,
#   'launched': '2015-09-17 16:39:03',
#   'pledged': 257275.0,
#   'state': 'failed',
#   'backers': 239.0,
#   'country': 'US',
#   'usd_pledged': 257275.0,
#   'usd_pledged_real': 257275.0},
#  {'_id': ObjectId('601d0a42941a132c4d24529c'),
#   'ID': 867411036,
#   'name': 'The Duchess - A Gaming Table from BoardGameTables.com',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-13',
#   'goal': 40000.0,
#   'launched': '2016-06-09 15:43:47',
#   'pledged': 2592231.77,
#   'state': 'successful',
#   'backers': 3364.0,
#   'country': 'US',
#   'usd_pledged': 1570447.77,
#   'usd_pledged_real': 2592231.77},
#  {'_id': ObjectId('601d0a42941a132c4d24561b'),
#   'ID': 2128094718,
#   'name': 'Code Monkey Save World',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-05-15',
#   'goal': 39000.0,
#   'launched': '2013-04-15 15:18:36',
#   'pledged': 340270.07,
#   'state': 'successful',
#   'backers': 8452.0,
#   'country': 'US',
#   'usd_pledged': 340270.07,
#   'usd_pledged_real': 340270.07},
#  {'_id': ObjectId('601d0a42941a132c4d245654'),
#   'ID': 1253340997,
#   'name': 'Worldï¿½s first roast-grind-brew coffee machine',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-12-08',
#   'goal': 135000.0,
#   'launched': '2013-11-12 15:00:06',
#   'pledged': 681461.0,
#   'state': 'successful',
#   'backers': 2254.0,
#   'country': 'US',
#   'usd_pledged': 681461.0,
#   'usd_pledged_real': 681461.0},
#  {'_id': ObjectId('601d0a42941a132c4d2456fd'),
#   'ID': 1036153335,
#   'name': 'MagSphere & MagBounce Flash Diffusers - by MagMod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 50000.0,
#   'launched': '2014-10-29 15:10:02',
#   'pledged': 310348.0,
#   'state': 'successful',
#   'backers': 2322.0,
#   'country': 'US',
#   'usd_pledged': 310348.0,
#   'usd_pledged_real': 310348.0},
#  {'_id': ObjectId('601d0a42941a132c4d24579e'),
#   'ID': 731137767,
#   'name': 'Finex Cast Iron Skillet: A Beloved Classic Updated',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-18',
#   'goal': 25000.0,
#   'launched': '2013-10-17 02:51:37',
#   'pledged': 211027.66,
#   'state': 'successful',
#   'backers': 1558.0,
#   'country': 'US',
#   'usd_pledged': 211027.66,
#   'usd_pledged_real': 211027.66},
#  {'_id': ObjectId('601d0a42941a132c4d2457cd'),
#   'ID': 459943590,
#   'name': 'Ctrl+Alt+Del 1.0: The Box Set',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2015-06-03',
#   'goal': 150000.0,
#   'launched': '2015-05-04 06:05:45',
#   'pledged': 665725.94,
#   'state': 'successful',
#   'backers': 5553.0,
#   'country': 'US',
#   'usd_pledged': 665725.94,
#   'usd_pledged_real': 665725.94},
#  {'_id': ObjectId('601d0a42941a132c4d245823'),
#   'ID': 925988701,
#   'name': 'Art Story',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-23',
#   'goal': 350000.0,
#   'launched': '2013-07-07 23:34:52',
#   'pledged': 365670.0,
#   'state': 'successful',
#   'backers': 1785.0,
#   'country': 'US',
#   'usd_pledged': 365670.0,
#   'usd_pledged_real': 365670.0},
#  {'_id': ObjectId('601d0a42941a132c4d245a45'),
#   'ID': 926038987,
#   'name': "H-Hour: World's Elite",
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-07-07',
#   'goal': 200000.0,
#   'launched': '2013-06-07 23:00:45',
#   'pledged': 252662.28,
#   'state': 'successful',
#   'backers': 2772.0,
#   'country': 'US',
#   'usd_pledged': 252662.28,
#   'usd_pledged_real': 252662.28},
#  {'_id': ObjectId('601d0a42941a132c4d245c0b'),
#   'ID': 1911751690,
#   'name': 'Dungeon of Doom: Handcrafted Game Terrain by Dwarven Forge',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 100000.0,
#   'launched': '2017-06-17 17:00:09',
#   'pledged': 3055118.0,
#   'state': 'successful',
#   'backers': 2897.0,
#   'country': 'US',
#   'usd_pledged': 1397310.0,
#   'usd_pledged_real': 3055118.0},
#  {'_id': ObjectId('601d0a42941a132c4d245e91'),
#   'ID': 1310046506,
#   'name': 'Click - The First Watch Band Adapter for Apple Watch!',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-18',
#   'goal': 30000.0,
#   'launched': '2015-03-18 23:35:57',
#   'pledged': 216436.0,
#   'state': 'successful',
#   'backers': 5538.0,
#   'country': 'US',
#   'usd_pledged': 216436.0,
#   'usd_pledged_real': 216436.0},
#  {'_id': ObjectId('601d0a42941a132c4d245ef5'),
#   'ID': 443600622,
#   'name': 'Passion Planner: Get One, Give One',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-11-24',
#   'goal': 15000.0,
#   'launched': '2015-10-13 19:00:52',
#   'pledged': 706287.0,
#   'state': 'successful',
#   'backers': 16335.0,
#   'country': 'US',
#   'usd_pledged': 706287.0,
#   'usd_pledged_real': 706287.0},
#  {'_id': ObjectId('601d0a42941a132c4d245f08'),
#   'ID': 22304643,
#   'name': 'Kill Doctor Lucky',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-14',
#   'goal': 40000.0,
#   'launched': '2015-10-13 21:01:01',
#   'pledged': 210086.5,
#   'state': 'successful',
#   'backers': 2711.0,
#   'country': 'US',
#   'usd_pledged': 210086.5,
#   'usd_pledged_real': 210086.5},
#  {'_id': ObjectId('601d0a42941a132c4d2460b8'),
#   'ID': 1026598212,
#   'name': 'Numenera: Into the Ninth World',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-09-10',
#   'goal': 20000.0,
#   'launched': '2015-08-05 18:04:36',
#   'pledged': 417560.0,
#   'state': 'successful',
#   'backers': 3317.0,
#   'country': 'US',
#   'usd_pledged': 417560.0,
#   'usd_pledged_real': 417560.0},
#  {'_id': ObjectId('601d0a42941a132c4d2460d9'),
#   'ID': 248979774,
#   'name': 'ZRRO - Play 300,000 touch games on your TV!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-31',
#   'goal': 200000.0,
#   'launched': '2015-02-17 19:20:19',
#   'pledged': 200392.0,
#   'state': 'successful',
#   'backers': 762.0,
#   'country': 'US',
#   'usd_pledged': 200392.0,
#   'usd_pledged_real': 200392.0},
#  {'_id': ObjectId('601d0a42941a132c4d2460fd'),
#   'ID': 1636168806,
#   'name': 'StoneTether - The Smallest Tracking Device at Long Range',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 15000.0,
#   'launched': '2014-11-03 17:39:21',
#   'pledged': 366199.0,
#   'state': 'successful',
#   'backers': 6927.0,
#   'country': 'US',
#   'usd_pledged': 366199.0,
#   'usd_pledged_real': 366199.0},
#  {'_id': ObjectId('601d0a42941a132c4d2461f1'),
#   'ID': 415727459,
#   'name': 'FormBox: A Desktop Vacuum Former That Makes Beautiful Things',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-06-03',
#   'goal': 50000.0,
#   'launched': '2016-05-02 19:22:23',
#   'pledged': 588775.55,
#   'state': 'successful',
#   'backers': 1745.0,
#   'country': 'US',
#   'usd_pledged': 588775.55,
#   'usd_pledged_real': 588775.55},
#  {'_id': ObjectId('601d0a42941a132c4d2462d8'),
#   'ID': 815224727,
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-01-07',
#   'goal': 250000.0,
#   'launched': '2013-12-04 18:56:58',
#   'pledged': 310225.01,
#   'state': 'successful',
#   'backers': 2026.0,
#   'country': 'US',
#   'usd_pledged': 310225.01,
#   'usd_pledged_real': 310225.01},
#  {'_id': ObjectId('601d0a42941a132c4d246628'),
#   'ID': 926266608,
#   'name': 'Modbook Pro X ï¿½ 15.4" Retina Quad-Core Mac OS X Tablet',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-07',
#   'goal': 150000.0,
#   'launched': '2014-07-30 18:57:35',
#   'pledged': 318244.34,
#   'state': 'successful',
#   'backers': 331.0,
#   'country': 'US',
#   'usd_pledged': 318244.34,
#   'usd_pledged_real': 318244.34},
#  {'_id': ObjectId('601d0a42941a132c4d24663c'),
#   'ID': 697445050,
#   'name': 'Remix IO - A 4K, Nougat-powered, All-in-One device',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-19',
#   'goal': 250000.0,
#   'launched': '2016-10-20 16:57:37',
#   'pledged': 598268.0,
#   'state': 'successful',
#   'backers': 4435.0,
#   'country': 'US',
#   'usd_pledged': 233222.0,
#   'usd_pledged_real': 598268.0},
#  {'_id': ObjectId('601d0a42941a132c4d2467ba'),
#   'ID': 849119531,
#   'name': 'Fief - France 1429',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-11',
#   'goal': 20000.0,
#   'launched': '2013-12-28 20:01:26',
#   'pledged': 408519.36,
#   'state': 'successful',
#   'backers': 4021.0,
#   'country': 'US',
#   'usd_pledged': 408519.36,
#   'usd_pledged_real': 408519.36},
#  {'_id': ObjectId('601d0a42941a132c4d246829'),
#   'ID': 776266348,
#   'name': 'Posthuman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-24',
#   'goal': 27000.0,
#   'launched': '2015-03-25 22:52:43',
#   'pledged': 346071.0,
#   'state': 'successful',
#   'backers': 5323.0,
#   'country': 'US',
#   'usd_pledged': 346071.0,
#   'usd_pledged_real': 346071.0},
#  {'_id': ObjectId('601d0a42941a132c4d246864'),
#   'ID': 1942255469,
#   'name': 'Luminoodle: Versatile USB Lighting Solution',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-15',
#   'goal': 10000.0,
#   'launched': '2015-09-15 16:00:10',
#   'pledged': 388464.1,
#   'state': 'successful',
#   'backers': 6768.0,
#   'country': 'US',
#   'usd_pledged': 388464.1,
#   'usd_pledged_real': 388464.1},
#  {'_id': ObjectId('601d0a42941a132c4d246938'),
#   'ID': 1192070348,
#   'name': 'Glowdeck - A companion for your smartphone.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-05-01',
#   'goal': 30000.0,
#   'launched': '2014-03-18 20:52:29',
#   'pledged': 209669.0,
#   'state': 'successful',
#   'backers': 956.0,
#   'country': 'US',
#   'usd_pledged': 209669.0,
#   'usd_pledged_real': 209669.0},
#  {'_id': ObjectId('601d0a42941a132c4d246a2c'),
#   'ID': 1967287711,
#   'name': 'tinyTesla: the Little Singing Tesla Coil Anyone Can Build',
#   'category': 'DIY Electronics',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-15',
#   'goal': 20000.0,
#   'launched': '2014-07-16 19:48:29',
#   'pledged': 336271.05,
#   'state': 'successful',
#   'backers': 1568.0,
#   'country': 'US',
#   'usd_pledged': 336271.05,
#   'usd_pledged_real': 336271.05},
#  {'_id': ObjectId('601d0a42941a132c4d246a66'),
#   'ID': 2137602357,
#   'name': 'ZUNGLE : Wear the Beats',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 50000.0,
#   'launched': '2016-06-16 16:41:54',
#   'pledged': 1947035.0,
#   'state': 'successful',
#   'backers': 11349.0,
#   'country': 'US',
#   'usd_pledged': 207044.0,
#   'usd_pledged_real': 1947035.0},
#  {'_id': ObjectId('601d0a42941a132c4d246b37'),
#   'ID': 1288353288,
#   'name': 'ORION4Sight: Sunglasses On Steroids',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-13',
#   'goal': 9000.0,
#   'launched': '2014-08-12 18:37:49',
#   'pledged': 348449.0,
#   'state': 'successful',
#   'backers': 2881.0,
#   'country': 'US',
#   'usd_pledged': 348449.0,
#   'usd_pledged_real': 348449.0},
#  {'_id': ObjectId('601d0a42941a132c4d246cf0'),
#   'ID': 1669948790,
#   'name': 'Unknown Armies Third Edition Roleplaying Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 40000.0,
#   'launched': '2016-03-30 21:33:25',
#   'pledged': 266084.45,
#   'state': 'successful',
#   'backers': 2819.0,
#   'country': 'US',
#   'usd_pledged': 266084.45,
#   'usd_pledged_real': 266084.45},
#  {'_id': ObjectId('601d0a42941a132c4d246e5f'),
#   'ID': 474144967,
#   'name': 'Crowfall - Throne War PC MMO',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-26',
#   'goal': 800000.0,
#   'launched': '2015-02-24 14:00:26',
#   'pledged': 1766204.58,
#   'state': 'successful',
#   'backers': 16936.0,
#   'country': 'US',
#   'usd_pledged': 1766204.58,
#   'usd_pledged_real': 1766204.58},
#  {'_id': ObjectId('601d0a42941a132c4d246eeb'),
#   'ID': 969897193,
#   'name': 'Create wide-angle Bubble Bokeh: Trioplan 35+ Fine Art Lens',
#   'category': 'Photography',
#   'main_category': 'Photography',
#   'currency': 'USD',
#   'deadline': '2017-04-13',
#   'goal': 50000.0,
#   'launched': '2017-03-09 16:00:22',
#   'pledged': 595893.23,
#   'state': 'successful',
#   'backers': 774.0,
#   'country': 'US',
#   'usd_pledged': 239730.21,
#   'usd_pledged_real': 595893.23},
#  {'_id': ObjectId('601d0a42941a132c4d24724a'),
#   'ID': 1317644491,
#   'name': "Remix Mini - The World's First True Android PC.",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-29',
#   'goal': 50000.0,
#   'launched': '2015-07-15 14:55:55',
#   'pledged': 1647155.12,
#   'state': 'successful',
#   'backers': 21975.0,
#   'country': 'US',
#   'usd_pledged': 1647155.12,
#   'usd_pledged_real': 1647155.12},
#  {'_id': ObjectId('601d0a42941a132c4d2474d0'),
#   'ID': 434718627,
#   'name': 'Little Witch Academia 2',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-08-08',
#   'goal': 150000.0,
#   'launched': '2013-07-09 05:31:42',
#   'pledged': 625518.12,
#   'state': 'successful',
#   'backers': 7938.0,
#   'country': 'US',
#   'usd_pledged': 625518.12,
#   'usd_pledged_real': 625518.12},
#  {'_id': ObjectId('601d0a42941a132c4d2474e7'),
#   'ID': 375709459,
#   'name': 'Dead State: The Zombie Survival RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-05',
#   'goal': 150000.0,
#   'launched': '2012-06-05 23:31:17',
#   'pledged': 332635.58,
#   'state': 'successful',
#   'backers': 10096.0,
#   'country': 'US',
#   'usd_pledged': 332635.58,
#   'usd_pledged_real': 332635.58},
#  {'_id': ObjectId('601d0a42941a132c4d247c9d'),
#   'ID': 1117814212,
#   'name': 'SnapJet: Turn your smartphone into a polaroid film printer!',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-20',
#   'goal': 155000.0,
#   'launched': '2014-11-19 21:02:07',
#   'pledged': 210449.0,
#   'state': 'successful',
#   'backers': 1486.0,
#   'country': 'US',
#   'usd_pledged': 210449.0,
#   'usd_pledged_real': 210449.0},
#  {'_id': ObjectId('601d0a42941a132c4d247cf5'),
#   'ID': 879838135,
#   'name': 'BLAZAR: Aluminum Bluetooth Speaker & Artist Collaboration',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-09-01',
#   'goal': 90000.0,
#   'launched': '2013-07-23 16:06:37',
#   'pledged': 323696.99,
#   'state': 'successful',
#   'backers': 1769.0,
#   'country': 'US',
#   'usd_pledged': 323696.99,
#   'usd_pledged_real': 323696.99},
#  {'_id': ObjectId('601d0a42941a132c4d247db1'),
#   'ID': 881278489,
#   'name': "Halo Back: World's First Smart Screen Protector",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-12',
#   'goal': 20000.0,
#   'launched': '2015-05-12 18:31:05',
#   'pledged': 251089.0,
#   'state': 'successful',
#   'backers': 8018.0,
#   'country': 'US',
#   'usd_pledged': 251089.0,
#   'usd_pledged_real': 251089.0},
#  {'_id': ObjectId('601d0a42941a132c4d247f6b'),
#   'ID': 1066172240,
#   'name': 'Rum & Bones: Second Tide',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 80000.0,
#   'launched': '2016-04-11 21:01:01',
#   'pledged': 917864.02,
#   'state': 'successful',
#   'backers': 5794.0,
#   'country': 'US',
#   'usd_pledged': 917864.02,
#   'usd_pledged_real': 917864.02},
#  {'_id': ObjectId('601d0a42941a132c4d248451'),
#   'ID': 63646255,
#   'name': 'Girl Genius Volume 12 Printing and Reprint Frenzy!',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2013-06-03',
#   'goal': 55000.0,
#   'launched': '2013-05-15 20:29:28',
#   'pledged': 389079.03,
#   'state': 'successful',
#   'backers': 4441.0,
#   'country': 'US',
#   'usd_pledged': 389079.03,
#   'usd_pledged_real': 389079.03},
#  {'_id': ObjectId('601d0a42941a132c4d248605'),
#   'ID': 355247056,
#   'name': 'Project 562: Changing The Way We See Native America (Phase2)',
#   'category': 'Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2014-02-21',
#   'goal': 54000.0,
#   'launched': '2014-01-20 11:46:39',
#   'pledged': 213461.49,
#   'state': 'successful',
#   'backers': 3882.0,
#   'country': 'US',
#   'usd_pledged': 213461.49,
#   'usd_pledged_real': 213461.49},
#  {'_id': ObjectId('601d0a42941a132c4d2487f3'),
#   'ID': 1890358928,
#   'name': "De La Soul's NEW ALBUM",
#   'category': 'Hip-Hop',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2015-05-02',
#   'goal': 110000.0,
#   'launched': '2015-03-30 18:03:13',
#   'pledged': 600874.82,
#   'state': 'successful',
#   'backers': 11169.0,
#   'country': 'US',
#   'usd_pledged': 600874.82,
#   'usd_pledged_real': 600874.82},
#  {'_id': ObjectId('601d0a42941a132c4d248992'),
#   'ID': 1653048335,
#   'name': 'Machine of Death: The Game of Creative Assassination',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-03-20',
#   'goal': 23000.0,
#   'launched': '2013-02-14 22:55:11',
#   'pledged': 556596.17,
#   'state': 'successful',
#   'backers': 10666.0,
#   'country': 'US',
#   'usd_pledged': 556596.17,
#   'usd_pledged_real': 556596.17},
#  {'_id': ObjectId('601d0a42941a132c4d248a8a'),
#   'ID': 224730709,
#   'name': 'DRAGON WARRIORS:   a feature film starring James Marsters',
#   'category': 'Fantasy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-05-19',
#   'goal': 200000.0,
#   'launched': '2014-04-19 18:27:18',
#   'pledged': 216260.28,
#   'state': 'successful',
#   'backers': 1628.0,
#   'country': 'US',
#   'usd_pledged': 216260.28,
#   'usd_pledged_real': 216260.28},
#  {'_id': ObjectId('601d0a42941a132c4d248bfe'),
#   'ID': 1864259007,
#   'name': 'Xeko',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-07-21',
#   'goal': 250000.0,
#   'launched': '2012-05-22 16:29:50',
#   'pledged': 257870.61,
#   'state': 'successful',
#   'backers': 973.0,
#   'country': 'US',
#   'usd_pledged': 257870.61,
#   'usd_pledged_real': 257870.61},
#  {'_id': ObjectId('601d0a42941a132c4d248d36'),
#   'ID': 502128093,
#   'name': 'Electric Objects: A Computer Made for Art',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-08-07',
#   'goal': 25000.0,
#   'launched': '2014-07-08 16:35:51',
#   'pledged': 787612.73,
#   'state': 'successful',
#   'backers': 2246.0,
#   'country': 'US',
#   'usd_pledged': 787612.73,
#   'usd_pledged_real': 787612.73},
#  {'_id': ObjectId('601d0a42941a132c4d248d9c'),
#   'ID': 645282827,
#   'name': 'Sleep Shepherd Blue: A Sleep Tracker that HELPS You Sleep',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-03-25',
#   'goal': 25000.0,
#   'launched': '2016-02-24 13:53:03',
#   'pledged': 675184.5,
#   'state': 'successful',
#   'backers': 3233.0,
#   'country': 'US',
#   'usd_pledged': 675184.5,
#   'usd_pledged_real': 675184.5},
#  {'_id': ObjectId('601d0a42941a132c4d248e5a'),
#   'ID': 577887742,
#   'name': 'Redefining Swiss Automatic Watches by LIV',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-02-19',
#   'goal': 40000.0,
#   'launched': '2016-01-20 21:00:42',
#   'pledged': 1119029.85,
#   'state': 'successful',
#   'backers': 2169.0,
#   'country': 'US',
#   'usd_pledged': 1119029.85,
#   'usd_pledged_real': 1119029.85},
#  {'_id': ObjectId('601d0a42941a132c4d248f37'),
#   'ID': 863432111,
#   'name': 'The Lomography Daguerreotype Achromat 2.9/64 Art Lens',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-05-10',
#   'goal': 100000.0,
#   'launched': '2016-04-06 10:58:36',
#   'pledged': 927576.13,
#   'state': 'successful',
#   'backers': 2036.0,
#   'country': 'US',
#   'usd_pledged': 927576.13,
#   'usd_pledged_real': 927576.13},
#  {'_id': ObjectId('601d0a42941a132c4d249066'),
#   'ID': 1829930859,
#   'name': "PancakeBot - The world's first pancake printer!",
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-10',
#   'goal': 50000.0,
#   'launched': '2015-03-06 15:41:52',
#   'pledged': 460584.0,
#   'state': 'successful',
#   'backers': 2074.0,
#   'country': 'US',
#   'usd_pledged': 460584.0,
#   'usd_pledged_real': 460584.0},
#  {'_id': ObjectId('601d0a42941a132c4d2492a5'),
#   'ID': 1842403099,
#   'name': 'The Cyanide & Happiness Show',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-03-18',
#   'goal': 250000.0,
#   'launched': '2013-02-15 08:55:35',
#   'pledged': 770309.28,
#   'state': 'successful',
#   'backers': 14242.0,
#   'country': 'US',
#   'usd_pledged': 770309.28,
#   'usd_pledged_real': 770309.28},
#  {'_id': ObjectId('601d0a42941a132c4d2493a4'),
#   'ID': 1301018404,
#   'name': 'LOAD the Board Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-08',
#   'goal': 30000.0,
#   'launched': '2016-05-19 20:00:28',
#   'pledged': 215471.52,
#   'state': 'successful',
#   'backers': 1558.0,
#   'country': 'US',
#   'usd_pledged': 215471.52,
#   'usd_pledged_real': 215471.52},
#  {'_id': ObjectId('601d0a42941a132c4d249461'),
#   'ID': 726799615,
#   'name': 'PARKE: Premium Active Denim - Engineered for Performance',
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2013-11-01',
#   'goal': 20000.0,
#   'launched': '2013-09-17 14:45:29',
#   'pledged': 221509.0,
#   'state': 'successful',
#   'backers': 1784.0,
#   'country': 'US',
#   'usd_pledged': 221509.0,
#   'usd_pledged_real': 221509.0},
#  {'_id': ObjectId('601d0a42941a132c4d249475'),
#   'ID': 1877182337,
#   'name': 'PENXO | The most minimalistic 2mm lead holder pencil',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-06-11',
#   'goal': 8800.0,
#   'launched': '2015-05-06 06:35:46',
#   'pledged': 334211.0,
#   'state': 'successful',
#   'backers': 5764.0,
#   'country': 'US',
#   'usd_pledged': 334211.0,
#   'usd_pledged_real': 334211.0},
#  {'_id': ObjectId('601d0a42941a132c4d24956c'),
#   'ID': 1732240067,
#   'name': '1001 Knights',
#   'category': 'Anthologies',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2016-02-26',
#   'goal': 70000.0,
#   'launched': '2016-01-27 16:51:50',
#   'pledged': 299192.28,
#   'state': 'successful',
#   'backers': 3289.0,
#   'country': 'US',
#   'usd_pledged': 299192.28,
#   'usd_pledged_real': 299192.28},
#  {'_id': ObjectId('601d0a42941a132c4d2497db'),
#   'ID': 61500846,
#   'name': 'BedJet v2: Sleep inducing climate control just for your Bed',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-09-13',
#   'goal': 24000.0,
#   'launched': '2015-08-05 19:06:38',
#   'pledged': 1363381.0,
#   'state': 'successful',
#   'backers': 4023.0,
#   'country': 'US',
#   'usd_pledged': 1363381.0,
#   'usd_pledged_real': 1363381.0},
#  {'_id': ObjectId('601d0a42941a132c4d249b02'),
#   'ID': 3968895,
#   'name': 'RiffTrax will Riff GODZILLA & ANACONDA in Cinemas Nationwide',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2014-06-12',
#   'goal': 100000.0,
#   'launched': '2014-05-13 01:16:38',
#   'pledged': 265011.68,
#   'state': 'successful',
#   'backers': 4887.0,
#   'country': 'US',
#   'usd_pledged': 265011.68,
#   'usd_pledged_real': 265011.68},
#  {'_id': ObjectId('601d0a42941a132c4d249b9c'),
#   'ID': 345927017,
#   'name': 'PocketScan',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-16',
#   'goal': 50000.0,
#   'launched': '2014-06-16 14:41:13',
#   'pledged': 542732.32,
#   'state': 'successful',
#   'backers': 4586.0,
#   'country': 'US',
#   'usd_pledged': 542732.32,
#   'usd_pledged_real': 542732.32},
#  {'_id': ObjectId('601d0a42941a132c4d249d35'),
#   'ID': 1908063428,
#   'name': 'Kiwi 3 - OBD Car to Smartphone Interface Reinvented',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-08-07',
#   'goal': 25000.0,
#   'launched': '2015-06-23 20:19:53',
#   'pledged': 272851.0,
#   'state': 'successful',
#   'backers': 3801.0,
#   'country': 'US',
#   'usd_pledged': 272851.0,
#   'usd_pledged_real': 272851.0},
#  {'_id': ObjectId('601d0a42941a132c4d249e06'),
#   'ID': 1438957994,
#   'name': "Boss Fight Studio's Vitruvian H.A.C.K.S. Action Figures",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-12',
#   'goal': 75000.0,
#   'launched': '2014-06-03 04:52:35',
#   'pledged': 412270.0,
#   'state': 'successful',
#   'backers': 1198.0,
#   'country': 'US',
#   'usd_pledged': 412270.0,
#   'usd_pledged_real': 412270.0},
#  {'_id': ObjectId('601d0a42941a132c4d249f4e'),
#   'ID': 137993716,
#   'name': 'SpeedX Leopard | the first ever smart aero road bike',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-04-22',
#   'goal': 50000.0,
#   'launched': '2016-03-23 15:01:47',
#   'pledged': 2319876.0,
#   'state': 'successful',
#   'backers': 1251.0,
#   'country': 'US',
#   'usd_pledged': 2319876.0,
#   'usd_pledged_real': 2319876.0},
#  {'_id': ObjectId('601d0a42941a132c4d24a038'),
#   'ID': 656587023,
#   'name': 'Ticwatch S & E: A Truly Optimized Smartwatch',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-08-18',
#   'goal': 100000.0,
#   'launched': '2017-07-11 18:58:15',
#   'pledged': 3203762.0,
#   'state': 'successful',
#   'backers': 19251.0,
#   'country': 'US',
#   'usd_pledged': 774259.0,
#   'usd_pledged_real': 3203762.0},
#  {'_id': ObjectId('601d0a42941a132c4d24a084'),
#   'ID': 857799723,
#   'name': 'RiffTrax Live 2015: THE ROOM, MIAMI CONNECTION, SHARKNADO 2!',
#   'category': 'Comedy',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-03-21',
#   'goal': 75000.0,
#   'launched': '2015-02-19 21:13:23',
#   'pledged': 250303.24,
#   'state': 'successful',
#   'backers': 3842.0,
#   'country': 'US',
#   'usd_pledged': 250303.24,
#   'usd_pledged_real': 250303.24},
#  {'_id': ObjectId('601d0a42941a132c4d24a13b'),
#   'ID': 981149095,
#   'name': '"Be Here Now" ï¿½ The Andy Whitfield Story',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-07-23',
#   'goal': 200000.0,
#   'launched': '2012-06-08 22:04:11',
#   'pledged': 302810.91,
#   'state': 'successful',
#   'backers': 5265.0,
#   'country': 'US',
#   'usd_pledged': 302810.91,
#   'usd_pledged_real': 302810.91},
#  {'_id': ObjectId('601d0a42941a132c4d24a6eb'),
#   'ID': 1859509147,
#   'name': 'Super Dungeon Explore: Legends',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-11-11',
#   'goal': 80000.0,
#   'launched': '2015-10-21 20:59:58',
#   'pledged': 1290522.32,
#   'state': 'successful',
#   'backers': 6611.0,
#   'country': 'US',
#   'usd_pledged': 1290522.32,
#   'usd_pledged_real': 1290522.32},
#  {'_id': ObjectId('601d0a42941a132c4d24a7ba'),
#   'ID': 1552929469,
#   'name': "CHIP - The World's First Nine Dollar Computer",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-06',
#   'goal': 50000.0,
#   'launched': '2015-05-07 17:06:02',
#   'pledged': 2071927.56,
#   'state': 'successful',
#   'backers': 39560.0,
#   'country': 'US',
#   'usd_pledged': 2071927.56,
#   'usd_pledged_real': 2071927.56},
#  {'_id': ObjectId('601d0a42941a132c4d24a93b'),
#   'ID': 1280589435,
#   'name': 'New Studio Album from Toad the Wet Sprocket!',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-04',
#   'goal': 50000.0,
#   'launched': '2013-06-05 23:36:52',
#   'pledged': 264762.72,
#   'state': 'successful',
#   'backers': 6304.0,
#   'country': 'US',
#   'usd_pledged': 264762.72,
#   'usd_pledged_real': 264762.72},
#  {'_id': ObjectId('601d0a42941a132c4d24aa22'),
#   'ID': 1650287708,
#   'name': 'Capture Camera Clip System',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2011-07-16',
#   'goal': 10000.0,
#   'launched': '2011-05-02 20:22:51',
#   'pledged': 364698.64,
#   'state': 'successful',
#   'backers': 5258.0,
#   'country': 'US',
#   'usd_pledged': 364698.64,
#   'usd_pledged_real': 364698.64},
#  {'_id': ObjectId('601d0a42941a132c4d24aa3e'),
#   'ID': 1218533935,
#   'name': '3Dsimo mini - Make your vision come true',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-12',
#   'goal': 35000.0,
#   'launched': '2015-08-28 13:40:19',
#   'pledged': 229958.0,
#   'state': 'successful',
#   'backers': 1822.0,
#   'country': 'US',
#   'usd_pledged': 229958.0,
#   'usd_pledged_real': 229958.0},
#  {'_id': ObjectId('601d0a42941a132c4d24abf8'),
#   'ID': 1318194565,
#   'name': 'FUGU LUGGAGE: One Case For All Your Needs',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-12-13',
#   'goal': 50000.0,
#   'launched': '2014-11-03 17:25:53',
#   'pledged': 433684.0,
#   'state': 'successful',
#   'backers': 1541.0,
#   'country': 'US',
#   'usd_pledged': 433684.0,
#   'usd_pledged_real': 433684.0},
#  {'_id': ObjectId('601d0a42941a132c4d24ac42'),
#   'ID': 348146014,
#   'name': 'Artisan Dice Does Handcrafted Polyhedrals',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-05-01',
#   'goal': 9000.0,
#   'launched': '2013-03-12 20:08:35',
#   'pledged': 291920.97,
#   'state': 'successful',
#   'backers': 1174.0,
#   'country': 'US',
#   'usd_pledged': 291920.97,
#   'usd_pledged_real': 291920.97},
#  {'_id': ObjectId('601d0a42941a132c4d24acb8'),
#   'ID': 538111099,
#   'name': 'MagBeam - Fresnel Lens Flash Extender + Gobos, by MagMod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-04-15',
#   'goal': 25000.0,
#   'launched': '2016-03-01 14:58:40',
#   'pledged': 301234.0,
#   'state': 'successful',
#   'backers': 1776.0,
#   'country': 'US',
#   'usd_pledged': 301234.0,
#   'usd_pledged_real': 301234.0},
#  {'_id': ObjectId('601d0a42941a132c4d24acee'),
#   'ID': 1577713248,
#   'name': 'Raise3D 3D Printers - Raise the Standard of 3D Printing',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-11-13',
#   'goal': 50000.0,
#   'launched': '2015-10-14 19:59:45',
#   'pledged': 445892.0,
#   'state': 'successful',
#   'backers': 348.0,
#   'country': 'US',
#   'usd_pledged': 445892.0,
#   'usd_pledged_real': 445892.0},
#  {'_id': ObjectId('601d0a42941a132c4d24ae53'),
#   'ID': 185659343,
#   'name': 'UBIK UNO: The Bezeless Smartphone at an Unbeatable Price',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-09-04',
#   'goal': 200000.0,
#   'launched': '2015-07-21 13:47:44',
#   'pledged': 241925.0,
#   'state': 'successful',
#   'backers': 766.0,
#   'country': 'US',
#   'usd_pledged': 241925.0,
#   'usd_pledged_real': 241925.0},
#  {'_id': ObjectId('601d0a42941a132c4d24af23'),
#   'ID': 355636922,
#   'name': 'MAGBELT - A magnetic belt that fits perfectly to your waist.',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-07-19',
#   'goal': 7500.0,
#   'launched': '2015-06-03 12:06:42',
#   'pledged': 583544.56,
#   'state': 'successful',
#   'backers': 9707.0,
#   'country': 'US',
#   'usd_pledged': 583544.56,
#   'usd_pledged_real': 583544.56},
#  {'_id': ObjectId('601d0a42941a132c4d24b0ab'),
#   'ID': 703110157,
#   'name': 'Beasts of the Mesozoic: Raptor Series Action Figures',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-05-27',
#   'goal': 125000.0,
#   'launched': '2016-04-27 18:00:50',
#   'pledged': 351753.52,
#   'state': 'successful',
#   'backers': 2661.0,
#   'country': 'US',
#   'usd_pledged': 351753.52,
#   'usd_pledged_real': 351753.52},
#  {'_id': ObjectId('601d0a42941a132c4d24b1d6'),
#   'ID': 1336092748,
#   'name': "Beastgrip Pro the world's best camera rig for smartphones",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-24',
#   'goal': 50000.0,
#   'launched': '2015-03-25 16:56:06',
#   'pledged': 265897.0,
#   'state': 'successful',
#   'backers': 1752.0,
#   'country': 'US',
#   'usd_pledged': 265897.0,
#   'usd_pledged_real': 265897.0},
#  {'_id': ObjectId('601d0a42941a132c4d24b24b'),
#   'ID': 1931115500,
#   'name': 'Karmaka ï¿½ A tactical card game for 2-4 souls',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-02-18',
#   'goal': 20000.0,
#   'launched': '2016-01-19 15:48:03',
#   'pledged': 220852.58,
#   'state': 'successful',
#   'backers': 7198.0,
#   'country': 'US',
#   'usd_pledged': 220852.58,
#   'usd_pledged_real': 220852.58},
#  {'_id': ObjectId('601d0a42941a132c4d24b257'),
#   'ID': 1897028933,
#   'name': 'Revols - Premium Quick Custom-Fit Wireless Earphones',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-01-08',
#   'goal': 100000.0,
#   'launched': '2015-11-09 13:57:15',
#   'pledged': 2530756.27,
#   'state': 'successful',
#   'backers': 10569.0,
#   'country': 'US',
#   'usd_pledged': 2530756.27,
#   'usd_pledged_real': 2530756.27},
#  {'_id': ObjectId('601d0a42941a132c4d24b25e'),
#   'ID': 664982962,
#   'name': 'Princess Awesome',
#   'category': 'Childrenswear',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-03-05',
#   'goal': 35000.0,
#   'launched': '2015-02-03 16:21:57',
#   'pledged': 215691.0,
#   'state': 'successful',
#   'backers': 3218.0,
#   'country': 'US',
#   'usd_pledged': 215691.0,
#   'usd_pledged_real': 215691.0},
#  {'_id': ObjectId('601d0a42941a132c4d24b29f'),
#   'ID': 487048791,
#   'name': 'HAVOK - Disrupting Luxury Watches',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-03-07',
#   'goal': 15000.0,
#   'launched': '2015-01-06 17:41:50',
#   'pledged': 443777.05,
#   'state': 'successful',
#   'backers': 4435.0,
#   'country': 'US',
#   'usd_pledged': 443777.05,
#   'usd_pledged_real': 443777.05},
#  {'_id': ObjectId('601d0a42941a132c4d24b395'),
#   'ID': 197718885,
#   'name': 'Saving Capitalism - Starring Robert Reich',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2016-05-06',
#   'goal': 256500.0,
#   'launched': '2016-04-06 23:04:40',
#   'pledged': 298436.53,
#   'state': 'successful',
#   'backers': 3790.0,
#   'country': 'US',
#   'usd_pledged': 298436.53,
#   'usd_pledged_real': 298436.53},
#  {'_id': ObjectId('601d0a42941a132c4d24b42c'),
#   'ID': 257342308,
#   'name': 'goTenna Mesh: Off-Grid, People-Powered Connectivity Anywhere',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-10-28',
#   'goal': 150000.0,
#   'launched': '2016-09-28 15:46:22',
#   'pledged': 582473.0,
#   'state': 'successful',
#   'backers': 2902.0,
#   'country': 'US',
#   'usd_pledged': 201555.0,
#   'usd_pledged_real': 582473.0},
#  {'_id': ObjectId('601d0a42941a132c4d24b569'),
#   'ID': 1420270001,
#   'name': 'Grim Dawn',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-19',
#   'goal': 280000.0,
#   'launched': '2012-04-17 12:34:43',
#   'pledged': 537515.31,
#   'state': 'successful',
#   'backers': 12457.0,
#   'country': 'US',
#   'usd_pledged': 537515.31,
#   'usd_pledged_real': 537515.31},
#  {'_id': ObjectId('601d0a42941a132c4d24b717'),
#   'ID': 355273044,
#   'name': 'Portable Console for PC games - PGS',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-31',
#   'goal': 100000.0,
#   'launched': '2016-07-01 00:01:58',
#   'pledged': 302836.0,
#   'state': 'canceled',
#   'backers': 1184.0,
#   'country': 'US',
# ...
#   'name': 'Boss Monster: The Next Level',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-28',
#   'goal': 25000.0,
#   'launched': '2015-04-13 15:03:50',
#   'pledged': 335618.85,
#   'state': 'successful',
#   'backers': 6891.0,
#   'country': 'US',
#   'usd_pledged': 335618.85,
#   'usd_pledged_real': 335618.85},
#  {'_id': ObjectId('601d0a43941a132c4d264d87'),
#   'ID': 152665462,
#   'name': 'An Honest Liar: The Amazing Randi Story',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-02-15',
#   'goal': 148000.0,
#   'launched': '2013-01-14 19:00:29',
#   'pledged': 246989.16,
#   'state': 'successful',
#   'backers': 3096.0,
#   'country': 'US',
#   'usd_pledged': 246989.16,
#   'usd_pledged_real': 246989.16},
#  {'_id': ObjectId('601d0a43941a132c4d264e79'),
#   'ID': 1719674104,
#   'name': 'Petcube ï¿½ stay closer to your pet',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-05',
#   'goal': 100000.0,
#   'launched': '2013-09-24 16:57:01',
#   'pledged': 251225.99,
#   'state': 'successful',
#   'backers': 1758.0,
#   'country': 'US',
#   'usd_pledged': 251225.99,
#   'usd_pledged_real': 251225.99},
#  {'_id': ObjectId('601d0a43941a132c4d264eff'),
#   'ID': 1616591982,
#   'name': 'AllSteady-6Pro DSLR/Red 3-Axis Gimbal Stabilizer',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-02-26',
#   'goal': 10000.0,
#   'launched': '2015-02-04 23:38:07',
#   'pledged': 206751.45,
#   'state': 'successful',
#   'backers': 136.0,
#   'country': 'US',
#   'usd_pledged': 206751.45,
#   'usd_pledged_real': 206751.45},
#  {'_id': ObjectId('601d0a43941a132c4d26503d'),
#   'ID': 227311545,
#   'name': 'BOOKNITURE- Furniture Hidden in a Book',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-03-18',
#   'goal': 50000.0,
#   'launched': '2015-02-06 16:41:06',
#   'pledged': 449969.0,
#   'state': 'successful',
#   'backers': 4007.0,
#   'country': 'US',
#   'usd_pledged': 449969.0,
#   'usd_pledged_real': 449969.0},
#  {'_id': ObjectId('601d0a43941a132c4d26508f'),
#   'ID': 1928575021,
#   'name': 'PowerUp 3.0 - Smartphone Controlled Paper Airplane',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-01-25',
#   'goal': 50000.0,
#   'launched': '2013-11-26 15:59:58',
#   'pledged': 1232612.55,
#   'state': 'successful',
#   'backers': 21412.0,
#   'country': 'US',
#   'usd_pledged': 1232612.55,
#   'usd_pledged_real': 1232612.55},
#  {'_id': ObjectId('601d0a43941a132c4d2651cc'),
#   'ID': 1652718766,
#   'name': 'Ube WiFi Connected Smart Light Dimmer',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-04-05',
#   'goal': 280000.0,
#   'launched': '2013-02-19 03:20:32',
#   'pledged': 307600.01,
#   'state': 'successful',
#   'backers': 1308.0,
#   'country': 'US',
#   'usd_pledged': 307600.01,
#   'usd_pledged_real': 307600.01},
#  {'_id': ObjectId('601d0a43941a132c4d2652c7'),
#   'ID': 985162833,
#   'name': 'Full-size reissue of the NYCTA Graphics Standards Manual.',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-10-10',
#   'goal': 108000.0,
#   'launched': '2014-09-10 13:15:43',
#   'pledged': 802812.9,
#   'state': 'successful',
#   'backers': 6718.0,
#   'country': 'US',
#   'usd_pledged': 802812.9,
#   'usd_pledged_real': 802812.9},
#  {'_id': ObjectId('601d0a43941a132c4d265319'),
#   'ID': 1758139953,
#   'name': 'The Gamers: Hands of Fate',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-08',
#   'goal': 320000.0,
#   'launched': '2012-07-18 04:57:56',
#   'pledged': 405916.78,
#   'state': 'successful',
#   'backers': 4311.0,
#   'country': 'US',
#   'usd_pledged': 405916.78,
#   'usd_pledged_real': 405916.78},
#  {'_id': ObjectId('601d0a43941a132c4d26533d'),
#   'ID': 567888025,
#   'name': 'HomeBiogas 2.0: Transforms Your Food Waste Into Clean Energy',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-12-13',
#   'goal': 75000.0,
#   'launched': '2017-11-01 12:50:14',
#   'pledged': 490319.0,
#   'state': 'successful',
#   'backers': 677.0,
#   'country': 'US',
#   'usd_pledged': 241707.0,
#   'usd_pledged_real': 490319.0},
#  {'_id': ObjectId('601d0a43941a132c4d265358'),
#   'ID': 1332810988,
#   'name': 'Pen Type-A : A minimal pen',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2011-08-15',
#   'goal': 2500.0,
#   'launched': '2011-07-16 20:16:54',
#   'pledged': 281989.75,
#   'state': 'successful',
#   'backers': 4048.0,
#   'country': 'US',
#   'usd_pledged': 281989.75,
#   'usd_pledged_real': 281989.75},
#  {'_id': ObjectId('601d0a43941a132c4d265383'),
#   'ID': 612880945,
#   'name': 'Point: A softer take on home security.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-12-04',
#   'goal': 50000.0,
#   'launched': '2014-11-04 17:59:41',
#   'pledged': 238366.0,
#   'state': 'successful',
#   'backers': 2005.0,
#   'country': 'US',
#   'usd_pledged': 238366.0,
#   'usd_pledged_real': 238366.0},
#  {'_id': ObjectId('601d0a43941a132c4d2654af'),
#   'ID': 729484586,
#   'name': 'Time of Legends: Joan of Arc',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-11-10',
#   'goal': 100000.0,
#   'launched': '2017-10-10 21:00:05',
#   'pledged': 2152285.02,
#   'state': 'successful',
#   'backers': 9987.0,
#   'country': 'US',
#   'usd_pledged': 355231.0,
#   'usd_pledged_real': 2152285.02},
#  {'_id': ObjectId('601d0a43941a132c4d2654e3'),
#   'ID': 658110891,
#   'name': 'Smart Herb Garden by Click & Grow',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-04-30',
#   'goal': 75000.0,
#   'launched': '2013-03-27 13:02:49',
#   'pledged': 625851.72,
#   'state': 'successful',
#   'backers': 10477.0,
#   'country': 'US',
#   'usd_pledged': 625851.72,
#   'usd_pledged_real': 625851.72},
#  {'_id': ObjectId('601d0a43941a132c4d26569f'),
#   'ID': 1948827936,
#   'name': 'Through the Breach: A Malifaux Roleplaying Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-01-11',
#   'goal': 30000.0,
#   'launched': '2012-11-28 23:17:40',
#   'pledged': 243945.43,
#   'state': 'successful',
#   'backers': 1546.0,
#   'country': 'US',
#   'usd_pledged': 243945.43,
#   'usd_pledged_real': 243945.43},
#  {'_id': ObjectId('601d0a43941a132c4d26578a'),
#   'ID': 2096075781,
#   'name': 'Pathfinder: Kingmaker',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 500000.0,
#   'launched': '2017-06-06 16:32:25',
#   'pledged': 909057.32,
#   'state': 'successful',
#   'backers': 18351.0,
#   'country': 'US',
#   'usd_pledged': 257647.0,
#   'usd_pledged_real': 909057.32},
#  {'_id': ObjectId('601d0a43941a132c4d2658b8'),
#   'ID': 1812220599,
#   'name': "Noke: The World's First Bluetooth Padlock",
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-09-17',
#   'goal': 100000.0,
#   'launched': '2014-08-18 13:02:49',
#   'pledged': 652828.81,
#   'state': 'successful',
#   'backers': 6108.0,
#   'country': 'US',
#   'usd_pledged': 652828.81,
#   'usd_pledged_real': 652828.81},
#  {'_id': ObjectId('601d0a43941a132c4d265b89'),
#   'ID': 1911111579,
#   'name': 'Two Guys SpaceVenture - by the creators of Space Quest',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-12',
#   'goal': 500000.0,
#   'launched': '2012-05-08 19:27:38',
#   'pledged': 539767.64,
#   'state': 'successful',
#   'backers': 10809.0,
#   'country': 'US',
#   'usd_pledged': 539767.64,
#   'usd_pledged_real': 539767.64},
#  {'_id': ObjectId('601d0a43941a132c4d265bc6'),
#   'ID': 450099426,
#   'name': 'The Everyday Backpack, Tote, and Sling',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-10',
#   'goal': 500000.0,
#   'launched': '2016-07-13 00:47:35',
#   'pledged': 6565782.5,
#   'state': 'successful',
#   'backers': 26359.0,
#   'country': 'US',
#   'usd_pledged': 1462611.0,
#   'usd_pledged_real': 6565782.5},
#  {'_id': ObjectId('601d0a43941a132c4d265d5d'),
#   'ID': 1645606141,
#   'name': 'PrioVR: Suit up. Game on.',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-03-31',
#   'goal': 75000.0,
#   'launched': '2014-02-14 16:00:06',
#   'pledged': 322103.09,
#   'state': 'successful',
#   'backers': 854.0,
#   'country': 'US',
#   'usd_pledged': 322103.09,
#   'usd_pledged_real': 322103.09},
#  {'_id': ObjectId('601d0a43941a132c4d265e13'),
#   'ID': 1901440175,
#   'name': 'Customizable 3D Printed Tabletop Miniatures',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-02-18',
#   'goal': 95000.0,
#   'launched': '2014-01-13 19:59:58',
#   'pledged': 360403.27,
#   'state': 'successful',
#   'backers': 5189.0,
#   'country': 'US',
#   'usd_pledged': 360403.27,
#   'usd_pledged_real': 360403.27},
#  {'_id': ObjectId('601d0a43941a132c4d265e3d'),
#   'ID': 1590570924,
#   'name': 'The Digital Bolex: The 1st Affordable Digital Cinema Camera',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-04-11',
#   'goal': 100000.0,
#   'launched': '2012-03-12 21:41:11',
#   'pledged': 262661.5,
#   'state': 'successful',
#   'backers': 440.0,
#   'country': 'US',
#   'usd_pledged': 262661.5,
#   'usd_pledged_real': 262661.5},
#  {'_id': ObjectId('601d0a43941a132c4d265ec9'),
#   'ID': 738065144,
#   'name': "8-in-1 EVOLUTION BRA: The World's Most Advanced Bra",
#   'category': 'Fashion',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-10-24',
#   'goal': 30000.0,
#   'launched': '2015-09-14 16:07:43',
#   'pledged': 1105177.5,
#   'state': 'successful',
#   'backers': 13642.0,
#   'country': 'US',
#   'usd_pledged': 1105177.5,
#   'usd_pledged_real': 1105177.5},
#  {'_id': ObjectId('601d0a43941a132c4d265f09'),
#   'ID': 279794621,
#   'name': 'Mega Manï¿½ The Board Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2014-01-19',
#   'goal': 70000.0,
#   'launched': '2013-12-12 18:58:35',
#   'pledged': 415041.0,
#   'state': 'successful',
#   'backers': 2639.0,
#   'country': 'US',
#   'usd_pledged': 415041.0,
#   'usd_pledged_real': 415041.0},
#  {'_id': ObjectId('601d0a43941a132c4d266212'),
#   'ID': 1719494931,
#   'name': 'Obduction',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-11-16',
#   'goal': 1100000.0,
#   'launched': '2013-10-17 15:06:31',
#   'pledged': 1321306.44,
#   'state': 'successful',
#   'backers': 22195.0,
#   'country': 'US',
#   'usd_pledged': 1321306.44,
#   'usd_pledged_real': 1321306.44},
#  {'_id': ObjectId('601d0a43941a132c4d266270'),
#   'ID': 1323185961,
#   'name': 'Sprite: portable and rugged.  A totally different drone.',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-14',
#   'goal': 200000.0,
#   'launched': '2015-05-15 05:52:37',
#   'pledged': 406061.0,
#   'state': 'successful',
#   'backers': 532.0,
#   'country': 'US',
#   'usd_pledged': 406061.0,
#   'usd_pledged_real': 406061.0},
#  {'_id': ObjectId('601d0a43941a132c4d266496'),
#   'ID': 363567675,
#   'name': '1979 REVOLUTION: Black Friday',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-16',
#   'goal': 395000.0,
#   'launched': '2013-11-13 13:22:42',
#   'pledged': 304741.5,
#   'state': 'failed',
#   'backers': 1653.0,
#   'country': 'US',
#   'usd_pledged': 304741.5,
#   'usd_pledged_real': 304741.5},
#  {'_id': ObjectId('601d0a43941a132c4d2664f2'),
#   'ID': 1127031239,
#   'name': 'TAKTIK: Premium Protection System for the iPhone',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-07-21',
#   'goal': 150000.0,
#   'launched': '2012-06-21 16:43:39',
#   'pledged': 680568.09,
#   'state': 'successful',
#   'backers': 4597.0,
#   'country': 'US',
#   'usd_pledged': 680568.09,
#   'usd_pledged_real': 680568.09},
#  {'_id': ObjectId('601d0a43941a132c4d2665b8'),
#   'ID': 472676658,
#   'name': 'Deathfire: Ruins of Nethermore RPG',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-07',
#   'goal': 390000.0,
#   'launched': '2013-11-06 21:01:00',
#   'pledged': 204344.55,
#   'state': 'failed',
#   'backers': 3815.0,
#   'country': 'US',
#   'usd_pledged': 204344.55,
#   'usd_pledged_real': 204344.55},
#  {'_id': ObjectId('601d0a43941a132c4d2666ed'),
#   'ID': 1113497210,
#   'name': 'Xia: Legends of a Drift System',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-06-22',
#   'goal': 100000.0,
#   'launched': '2013-05-17 09:17:18',
#   'pledged': 346772.24,
#   'state': 'successful',
#   'backers': 3293.0,
#   'country': 'US',
#   'usd_pledged': 346772.24,
#   'usd_pledged_real': 346772.24},
#  {'_id': ObjectId('601d0a43941a132c4d2667cb'),
#   'ID': 940858853,
#   'name': 'The Tribal Collection | Wooden Polarized Shades',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-07-01',
#   'goal': 6500.0,
#   'launched': '2015-06-01 07:13:59',
#   'pledged': 276164.01,
#   'state': 'successful',
#   'backers': 3196.0,
#   'country': 'US',
#   'usd_pledged': 276164.01,
#   'usd_pledged_real': 276164.01},
#  {'_id': ObjectId('601d0a43941a132c4d266a58'),
#   'ID': 247076610,
#   'name': 'Time of EVE: The Movie on Blu-ray',
#   'category': 'Animation',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2013-06-22',
#   'goal': 18000.0,
#   'launched': '2013-05-24 01:31:23',
#   'pledged': 215433.9,
#   'state': 'successful',
#   'backers': 2711.0,
#   'country': 'US',
#   'usd_pledged': 215433.9,
#   'usd_pledged_real': 215433.9},
#  {'_id': ObjectId('601d0a43941a132c4d266c00'),
#   'ID': 1270104074,
#   'name': 'Republique by Camouflaj + Logan',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-12',
#   'goal': 500000.0,
#   'launched': '2012-04-10 14:37:30',
#   'pledged': 555662.86,
#   'state': 'successful',
#   'backers': 11611.0,
#   'country': 'US',
#   'usd_pledged': 555662.86,
#   'usd_pledged_real': 555662.86},
#  {'_id': ObjectId('601d0a43941a132c4d266d03'),
#   'ID': 344582158,
#   'name': 'Hub+ for USB-C: Get your MacBook ports back.',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-06-16',
#   'goal': 35000.0,
#   'launched': '2015-05-05 19:08:49',
#   'pledged': 883460.8,
#   'state': 'successful',
#   'backers': 8019.0,
#   'country': 'US',
#   'usd_pledged': 883460.8,
#   'usd_pledged_real': 883460.8},
#  {'_id': ObjectId('601d0a43941a132c4d266e9a'),
#   'ID': 170672682,
#   'name': 'The Field Skillet: Lighter, Smoother Cast Iron',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-07',
#   'goal': 30000.0,
#   'launched': '2016-03-07 02:25:16',
#   'pledged': 1633361.53,
#   'state': 'successful',
#   'backers': 12553.0,
#   'country': 'US',
#   'usd_pledged': 1633361.53,
#   'usd_pledged_real': 1633361.53},
#  {'_id': ObjectId('601d0a43941a132c4d267157'),
#   'ID': 78391894,
#   'name': 'Handcrafted Dress Shoes Reinvented for the Modern Gentleman',
#   'category': 'Footwear',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2017-04-27',
#   'goal': 20000.0,
#   'launched': '2017-03-14 12:43:55',
#   'pledged': 1265430.42,
#   'state': 'successful',
#   'backers': 4422.0,
#   'country': 'US',
#   'usd_pledged': 339955.15,
#   'usd_pledged_real': 1265430.42},
#  {'_id': ObjectId('601d0a43941a132c4d267215'),
#   'ID': 238266124,
#   'name': 'Giant Unicorn Lamp',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-28',
#   'goal': 28500.0,
#   'launched': '2015-06-23 16:54:26',
#   'pledged': 250876.0,
#   'state': 'successful',
#   'backers': 3306.0,
#   'country': 'US',
#   'usd_pledged': 250876.0,
#   'usd_pledged_real': 250876.0}]

# %%
collection_ks.count_documents({"$and" : [{"country":'US'}, {"usd_pledged":{'$gte' : 200000}}]})
# Out:
# 461

# %% [markdown]
# ## Question 6

# %%
collection_ks.create_index([("name",  "text")])
# Out:
# 'name_text'

# %%
collection_ks.index_information()
# Out:
# {'_id_': {'v': 2, 'key': [('_id', 1)]},
#  'name_text': {'v': 2,
#   'key': [('_fts', 'text'), ('_ftsx', 1)],
#   'weights': SON([('name', 1)]),
#   'default_language': 'english',
#   'language_override': 'language',
#   'textIndexVersion': 3}}

# %%
collection_ks.count_documents( { "$text": { "$search": "Sport" } } )
# Out:
# 316
